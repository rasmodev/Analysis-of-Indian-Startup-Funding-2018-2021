# %% [markdown]
# ## Project Title:
# An analysis of the Indian start-up ecosystem

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# 1. Objectives
#
# The main objective of this analysis is to understand the Indian startup ecosystem, identify the key trends in funding, and explore the factors that influence a startup's ability to receive funding. The ultimate goal is to use this knowledge to enhance our chances of securing funding for our own startup.
#
# 2. Situation Assessment
#
# The Indian startup ecosystem has been growing rapidly over the last few years with increasing numbers of startups entering the market and attracting investment. However, the competition for funding is intense, and it can be challenging for new startups to secure the funding they need to grow and succeed. This analysis aims to explore the funding landscape in more detail, including the types of funding available, the sectors and industries that are receiving the most funding, and the factors that investors look for when deciding whether to invest in a startup.
#
# 3. Success criteria (Data Mining Goals)
#
# The success of this analysis will be measured by the insights and recommendations it generates to enhance our chances of securing funding. We will evaluate the success of our analysis based on the number of investors we are able to secure, the amount of funding we are able to receive, and our ability to use the insights gained from the analysis to inform our business strategy.
#
# 4. Project Plan
# 4.1 Data Understanding
#
# The dataset contains information on the Indian startup ecosystem for the years 2018, 2019, 2020, and 2021. The data includes details on the stage of funding, company, year founded, funding received, the investor, sector or industry, information about the company, founders, and location of headquarters. We will explore the dataset to gain a better understanding of the trends in funding and the factors that influence a startup's ability to receive funding.
#
# 4.2 Data Preparation
#
# We will clean and preprocess the dataset to ensure that it is ready for analysis. This will include removing any missing or duplicate data, transforming the data into a format suitable for analysis, and creating any new variables that may be needed to answer our research questions.

# %% [markdown]
# ## Questions and Hypotheses

# %% [markdown]
# ### Hypothesis
#
# Null hypothesis: There is no significant relationship between a startup's sector and its ability to secure funding.
# Alternative hypothesis: A startup's sector has a significant influence on its ability to secure funding.
#
#
# ### Questions
# Question 1: What is the trend in startup funding in India over the years?
#
# Question 2: What are the most common funding stage among Indian startups?
#
# Question 3: Average funding amount for a seed-stage investment in India over the years
#
# Question 4: Which sector has the highest average funding amount?
#
# Question 5: Is there a correlation between the location of a startup's headquarters and the amount of funding they receive?

# %% [markdown]
# ## Load Data

# %% [markdown]
# Installations

# %%
# !pip install squarify
# Out:
# Requirement already satisfied: squarify in c:\users\user\anaconda3\lib\site-packages (0.4.3)

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import datetime as dt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import squarify

# %% [markdown]
# Import All the datasets from 2018 to 2021

# %%
df_2018 = pd.read_csv("startup_funding2018.csv")
df_2019 = pd.read_csv("startup_funding2019.csv")
df_2020 = pd.read_csv("startup_funding2020.csv")
df_2021 = pd.read_csv("startup_funding2021.csv")

# %% [markdown]
# ## 1. The 2018 Dataset

# %%
df_2018.head(20)
# Out:
#                         Company Name  \
# 0                    TheCollegeFever
# 1                    Happy Cow Dairy
# 2                         MyLoanCare
# 3                        PayMe India
# 4                           Eunimart
# 5                             Hasura
# 6                          Tripshelf
# 7                       Hyperdata.IO
# 8                       Freightwalla
# 9                 Microchip Payments
# 10        BizCrum Infotech Pvt. Ltd.
# 11                           Emojifi
# 12                             Flock
# 13                         Freshboxx
# 14        Wide Mobility Mechatronics
# 15                           Pitstop
# 16                            Mihuru
# 17                              Fyle
# 18                          AppWharf
# 19  Antariksh Waste Ventures Pvt ltd
#
#                                              Industry Round/Series  \
# 0   Brand Marketing, Event Promotion, Marketing, S...         Seed
# 1                                Agriculture, Farming         Seed
# 2    Credit, Financial Services, Lending, Marketplace     Series A
# 3                         Financial Services, FinTech        Angel
# 4                  E-Commerce Platforms, Retail, SaaS         Seed
# 5                    Cloud Infrastructure, PaaS, SaaS         Seed
# 6                      Internet, Leisure, Marketplace         Seed
# 7                                     Market Research        Angel
# 8        Information Services, Information Technology         Seed
# 9                                     Mobile Payments         Seed
# 10                                         B2B, Shoes         Seed
# 11                                           Internet         Seed
# 12  Apps, Collaboration, Developer Platform, Enter...         Seed
# 13                                      Food Delivery         Seed
# 14                              Industrial Automation         Seed
# 15        Automotive, Search Engine, Service Industry         Seed
# 16                          Finance, Internet, Travel         Seed
# 17  Accounting, Business Information Systems, Busi...         Seed
# 18  Artificial Intelligence, Product Search, SaaS,...         Seed
# 19               Internet of Things, Waste Management         Seed
#
#           Amount                          Location  \
# 0         250000       Bangalore, Karnataka, India
# 1    ₹40,000,000        Mumbai, Maharashtra, India
# 2    ₹65,000,000           Gurgaon, Haryana, India
# 3        2000000       Noida, Uttar Pradesh, India
# 4              —  Hyderabad, Andhra Pradesh, India
# 5        1600000       Bengaluru, Karnataka, India
# 6    ₹16,000,000             Kalkaji, Delhi, India
# 7    ₹50,000,000  Hyderabad, Andhra Pradesh, India
# 8              —        Mumbai, Maharashtra, India
# 9              —       Bangalore, Karnataka, India
# 10             —               Delhi, Delhi, India
# 11             —       Bengaluru, Karnataka, India
# 12             —                       India, Asia
# 13             —           Hubli, Karnataka, India
# 14             —       Bangalore, Karnataka, India
# 15  ₹100,000,000       Bengaluru, Karnataka, India
# 16        150000        Mumbai, Maharashtra, India
# 17       1100000       Bengaluru, Karnataka, India
# 18             —           New Delhi, Delhi, India
# 19      ₹500,000        Chennai, Tamil Nadu, India
#
#                                         About Company
# 0   TheCollegeFever is a hub for fun, fiesta and f...
# 1   A startup which aggregates milk from dairy far...
# 2           Leading Online Loans Marketplace in India
# 3   PayMe India is an innovative FinTech organizat...
# 4   Eunimart is a one stop solution for merchants ...
# 5   Hasura is a platform that allows developers to...
# 6   Tripshelf is an online market place for holida...
# 7   Hyperdata combines advanced machine learning w...
# 8   Freightwalla is an international forwarder tha...
# 9   Microchip payments is a mobile-based payment a...
# 10           Building Transactionary B2B Marketplaces
# 11  Emojifi is an app that provides live emoji, st...
# 12  Flock is a real-time messaging and collaborati...
# 13  Freshboxx is incubated at Sandbox Startups, a ...
# 14  Wide Mobility Mechatronics is a Private Compan...
# 15  Pitstop offers general repair and maintenance ...
# 16  Mihuru is an online platform which gives micro...
# 17  Fyle is an intelligent expense management plat...
# 18  Appwharf is an intelligent assistant that help...
# 19                  Waste Management for Smart Cities

# %% [markdown]
# ## Cleaning The 2018 Dataset

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %% [markdown]
# ### i. Dropping the columns that are not needed for the analysis

# %%
# Drop the 'About Company' column as it is not needed for the analysis
df_2018 = df_2018.drop('About Company', axis=1)
df_2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount                          Location
# 0           Seed       250000       Bangalore, Karnataka, India
# 1           Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2       Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3          Angel      2000000       Noida, Uttar Pradesh, India
# 4           Seed            —  Hyderabad, Andhra Pradesh, India
# ..           ...          ...                               ...
# 521     Series C    225000000       Bangalore, Karnataka, India
# 522     Series A            —           Haryana, Haryana, India
# 523         Seed         7500        Mumbai, Maharashtra, India
# 524         Seed  ₹35,000,000        Mumbai, Maharashtra, India
# 525     Series C     35000000        Chennai, Tamil Nadu, India
#
# [526 rows x 5 columns]

# %% [markdown]
# ### ii. Checking for Duplicates in The Dataset

# %%
# Create a boolean mask that identifies duplicates
duplicates = df_2018.duplicated(keep=False)

# Count the number of occurrences of each unique value in the boolean mask
value_counts = duplicates.value_counts()

# The value counts
value_counts
# Out:
# False    524
# True       2
# dtype: int64

# %%
# Identify duplicate rows based on all columns
duplicates = df_2018[df_2018.duplicated(keep=False)]
duplicates
# Out:
#         Company Name                                           Industry  \
# 0    TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 348  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
#
#     Round/Series  Amount                     Location
# 0           Seed  250000  Bangalore, Karnataka, India
# 348         Seed  250000  Bangalore, Karnataka, India

# %%
# Drop one of the duplicates
df_2018.drop_duplicates(keep='first', inplace=True)

# %%
# Confirm whether duplicate rows have been dropped
duplicates = df_2018[df_2018.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Company Name, Industry, Round/Series, Amount, Location]
# Index: []

# %% [markdown]
# ### iii. Checking for Missing Values in The Dataset

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 525 entries, 0 to 525
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  525 non-null    object
#  1   Industry      525 non-null    object
#  2   Round/Series  525 non-null    object
#  3   Amount        525 non-null    object
#  4   Location      525 non-null    object
# dtypes: object(5)
# memory usage: 24.6+ KB

# %%
# check for Missing values in 2018 Dataset
missing_values = df_2018.isnull().sum()

# The number of missing values in each column
(missing_values)
# Out:
# Company Name    0
# Industry        0
# Round/Series    0
# Amount          0
# Location        0
# dtype: int64

# %% [raw]
# There are no missing values in the dataset. However, during data understanding, it was revealed that missing values were also denoted by dashes ("—").

# %%
# Missing Values are also denoted by dashes ("—")
# Replace dashes with NaN
df_2018.replace("—", np.nan, inplace=True)

# Check for missing values
missing_values = df_2018.isnull().sum()

# Missing values in each column
missing_values
# Out:
# Company Name      0
# Industry         30
# Round/Series      0
# Amount          148
# Location          0
# dtype: int64

# %% [raw]
# The DataFrame has 30 missing values in the 'Industry' column and 148 missing values in the 'Amount' column

# %% [markdown]
# #### a). Cleaning the 'Industry' column

# %%
# Convert 'Amount' column to numeric datatype, replacing any non-numeric values with NaN using the 'coerce' option
df_2018['Amount'] = pd.to_numeric(df_2018['Amount'], errors='coerce')

# Remove any comma
df_2018['Amount'] = df_2018['Amount'].astype(str).str.replace(',', '')

# Standardise the amount column by multiplying INR('₹') values by 0.0146 (Average currency rate INR to USD in 2018) Exchange Rates UK
df_2018.loc[df_2018['Amount'].astype(str).str.contains('₹'), 'Amount'] = df_2018.loc[df_2018['Amount'].astype(str).str.contains('₹'), 'Amount'].apply(lambda x: float(x.replace('₹', ''))/0.0146)

# Convert amounts with no currency symbol to USD using exchange rate of 1 USD = 1 USD
df_2018.loc[~df_2018['Amount'].astype(str).str.contains('₹'), 'Amount'] = df_2018.loc[~df_2018['Amount'].astype(str).str.contains('₹'), 'Amount'].apply(lambda x: float(x))

# Rename column "Amount" to "Amount($)"
df_2018.rename(columns={'Amount':'Amount($)'}, inplace=True)

# Convert Amount($) column from object to float datatype
df_2018['Amount($)'] = df_2018['Amount($)'].astype(float)

# The updated dataframe
df_2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series    Amount($)                          Location
# 0           Seed     250000.0       Bangalore, Karnataka, India
# 1           Seed          NaN        Mumbai, Maharashtra, India
# 2       Series A          NaN           Gurgaon, Haryana, India
# 3          Angel    2000000.0       Noida, Uttar Pradesh, India
# 4           Seed          NaN  Hyderabad, Andhra Pradesh, India
# ..           ...          ...                               ...
# 521     Series C  225000000.0       Bangalore, Karnataka, India
# 522     Series A          NaN           Haryana, Haryana, India
# 523         Seed       7500.0        Mumbai, Maharashtra, India
# 524         Seed          NaN        Mumbai, Maharashtra, India
# 525     Series C   35000000.0        Chennai, Tamil Nadu, India
#
# [525 rows x 5 columns]

# %%
df_2018['Industry'].describe
# Out:
# <bound method NDFrame.describe of 0      Brand Marketing, Event Promotion, Marketing, S...
# 1                                   Agriculture, Farming
# 2       Credit, Financial Services, Lending, Marketplace
# 3                            Financial Services, FinTech
# 4                     E-Commerce Platforms, Retail, SaaS
#                              ...
# 521     B2B, Business Development, Internet, Marketplace
# 522                                      Tourism, Travel
# 523           Food and Beverage, Food Delivery, Internet
# 524                               Information Technology
# 525           Biotechnology, Health Care, Pharmaceutical
# Name: Industry, Length: 525, dtype: object>

# %%
# Replace all missing values in the Industry column with the string "Unknown".
df_2018['Industry'] = df_2018['Industry'].fillna('Unknown')
df_2018.head(61)
# Out:
#                 Company Name  \
# 0            TheCollegeFever
# 1            Happy Cow Dairy
# 2                 MyLoanCare
# 3                PayMe India
# 4                   Eunimart
# ..                       ...
# 56                Propshop24
# 57                  myUpchar
# 58  MissMalini Entertainment
# 59                    Rooter
# 60                 ZestMoney
#
#                                              Industry Round/Series  \
# 0   Brand Marketing, Event Promotion, Marketing, S...         Seed
# 1                                Agriculture, Farming         Seed
# 2    Credit, Financial Services, Lending, Marketplace     Series A
# 3                         Financial Services, FinTech        Angel
# 4                  E-Commerce Platforms, Retail, SaaS         Seed
# ..                                                ...          ...
# 56                                         E-Commerce         Seed
# 57                    Health Care, Hospital, Wellness     Series A
# 58                                            Unknown         Seed
# 59                                             Sports         Seed
# 60                Big Data, Consumer Lending, FinTech     Series A
#
#      Amount($)                          Location
# 0     250000.0       Bangalore, Karnataka, India
# 1          NaN        Mumbai, Maharashtra, India
# 2          NaN           Gurgaon, Haryana, India
# 3    2000000.0       Noida, Uttar Pradesh, India
# 4          NaN  Hyderabad, Andhra Pradesh, India
# ..         ...                               ...
# 56    500000.0        Mumbai, Maharashtra, India
# 57   5000000.0           New Delhi, Delhi, India
# 58         NaN        Mumbai, Maharashtra, India
# 59         NaN                       India, Asia
# 60  13400000.0       Bangalore, Karnataka, India
#
# [61 rows x 5 columns]

# %% [markdown]
# #### b). Cleaning the 'Amount' column, replacing any non-numeric values ("—") with NaN, then converting the column to float datatype

# %%
# Plotting A histogram to visualize the distribution of funding amouns

# Histogram
plt.hist(df_2018['Amount($)'], bins=20)
plt.xlabel('Amount Raised in 2018 ($)')
plt.ylabel('Frequency')
plt.title('Distribution of Amount Raised in 2018')
plt.show()

# %% [raw]
# The histogram does not have a bell-shaped curve, indicating that it is not a normal distribution. Instead, it is asymmetrical indicating a positively skewed distribution since the data is clustered towards the left-hand side of the histogram, with a long tail extending out to the right.
#
# In this case, the the mean will be greater than the median, as the outliers on the right-hand side of the distribution pull the mean in that direction. Therefore, it would be appropriate to use the median as the measure of central tendency, as it is less affected by outliers than the mean.

# %%
# Replace NaN values in 'Amount($)' column with median
# Calculate the median of 'Amount($)' column
median_amount = df_2018['Amount($)'].median()

# Replace NaN values with median
df_2018['Amount($)'].fillna(median_amount, inplace=True)

# The updated dataframe
df_2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series    Amount($)                          Location
# 0           Seed     250000.0       Bangalore, Karnataka, India
# 1           Seed    1350000.0        Mumbai, Maharashtra, India
# 2       Series A    1350000.0           Gurgaon, Haryana, India
# 3          Angel    2000000.0       Noida, Uttar Pradesh, India
# 4           Seed    1350000.0  Hyderabad, Andhra Pradesh, India
# ..           ...          ...                               ...
# 521     Series C  225000000.0       Bangalore, Karnataka, India
# 522     Series A    1350000.0           Haryana, Haryana, India
# 523         Seed       7500.0        Mumbai, Maharashtra, India
# 524         Seed    1350000.0        Mumbai, Maharashtra, India
# 525     Series C   35000000.0        Chennai, Tamil Nadu, India
#
# [525 rows x 5 columns]

# %% [markdown]
# #### c). Cleaning the 'Location' column

# %%
# Bangalore and Bengaluru are different names for the same city.
# Replace all occurrences of 'Bengaluru' with 'Bangalore' to maintain consistency in our dataset.
df_2018['Location'] = df_2018['Location'].str.replace('Bengaluru', 'Bangalore', case=False)
df_2018['Location'] = df_2018['Location'].str.replace('Bangalore city', 'Bangalore', case=False)

df_2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series    Amount($)                          Location
# 0           Seed     250000.0       Bangalore, Karnataka, India
# 1           Seed    1350000.0        Mumbai, Maharashtra, India
# 2       Series A    1350000.0           Gurgaon, Haryana, India
# 3          Angel    2000000.0       Noida, Uttar Pradesh, India
# 4           Seed    1350000.0  Hyderabad, Andhra Pradesh, India
# ..           ...          ...                               ...
# 521     Series C  225000000.0       Bangalore, Karnataka, India
# 522     Series A    1350000.0           Haryana, Haryana, India
# 523         Seed       7500.0        Mumbai, Maharashtra, India
# 524         Seed    1350000.0        Mumbai, Maharashtra, India
# 525     Series C   35000000.0        Chennai, Tamil Nadu, India
#
# [525 rows x 5 columns]

# %%
# Split the 'Location' column into City, State and Country columns
df_2018[["City", "State", "Country"]] = df_2018["Location"].str.split(", ", expand=True)

# Drop the Location column as it has been split into City, State and Country columns
df_2018.drop("Location", axis=1, inplace=True)

# Drop the State column as it is not needed for the analysis
df_2018.drop("State", axis=1, inplace=True)

# Drop the Country column as it is not needed for the analysis
df_2018.drop("Country", axis=1, inplace=True)

df_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series  Amount($)       City
# 0         Seed   250000.0  Bangalore
# 1         Seed  1350000.0     Mumbai
# 2     Series A  1350000.0    Gurgaon
# 3        Angel  2000000.0      Noida
# 4         Seed  1350000.0  Hyderabad

# %% [markdown]
# #### d). Cleaning the 'Round/Series' column, replacing variations in the representation of the same funding stages with a consistent one

# %%
# Get unique funding Round/Series
df_2018['Round/Series'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed',
#        'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round'], dtype=object)

# %%
# Create a mapping dictionary that maps the variations to the standard representation
round_series_mapping = {'Pre-seed':['Pre-seed','Pre-Seed'],
                        'Equity': ['Private Equity', 'Post-IPO Equity'],
                        'Undisclosed': ['Undisclosed','Venture - Series Unknown','Funding Round', 
                        'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593'],
                        'Debt': ['Debt Financing', 'Post-IPO Debt']}

# use a lambda function with the apply() function to map each funding stage based on the mapping dictionary.
df_2018['Round/Series'] = df_2018['Round/Series'].apply(lambda x: next((k for k, v in round_series_mapping.items() if x in v), x))

# Confirm if changes have been effected
df_2018['Round/Series'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-seed', 'Equity',
#        'Undisclosed', 'Grant', 'Debt', 'Series H', 'Series C', 'Series E',
#        'Corporate Round', 'Series D', 'Secondary Market',
#        'Non-equity Assistance'], dtype=object)

# %% [raw]
# N/B: Any stage that is not present in the mapping dictionary will remain unchanged.

# %% [markdown]
# ### iv. Checking for Missing values and Confirming The data typtes again

# %%
# Check for Missing values in 2018 Dataset again
missing_values = df_2018.isnull().sum()

# Number of missing values in each column
missing_values
# Out:
# Company Name    0
# Industry        0
# Round/Series    0
# Amount($)       0
# City            0
# dtype: int64

# %% [raw]
# All Missing Values in the 2018 dataset have been handled

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %% [raw]
# The DataFrame is now formatted correctly to the respective data types.

# %% [markdown]
# ### v. Creating a new column 'Year' and setting it to 2018

# %%
# create a new column 'Year' and set it to 2020 to differentiate it from the other datasets
df_2018.insert(0,'Year', 2018)
df_2018.head()
# Out:
#    Year     Company Name                                           Industry  \
# 0  2018  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  2018  Happy Cow Dairy                               Agriculture, Farming
# 2  2018       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3  2018      PayMe India                        Financial Services, FinTech
# 4  2018         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series  Amount($)       City
# 0         Seed   250000.0  Bangalore
# 1         Seed  1350000.0     Mumbai
# 2     Series A  1350000.0    Gurgaon
# 3        Angel  2000000.0      Noida
# 4         Seed  1350000.0  Hyderabad

# %% [markdown]
# ## 2. The 2019 Dataset

# %%
df_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %% [markdown]
# # Cleaning The 2019 Dataset

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %% [markdown]
# ### i. Dropping the columns that are not needed for the analysis

# %%
# Drop the 'Founded' column
df_2019 = df_2019.drop('Founded', axis=1)

# Drop the 'What it does' column
df_2019 = df_2019.drop('What it does', axis=1)

# Drop the 'Founders' column
df_2019 = df_2019.drop('Founders', axis=1)

# Drop the 'Investor' column
df_2019 = df_2019.drop('Investor', axis=1)

df_2019.head()
# Out:
#     Company/Brand HeadQuarter           Sector     Amount($)          Stage
# 0  Bombay Shaving         NaN        Ecommerce    $6,300,000            NaN
# 1       Ruangguru      Mumbai           Edtech  $150,000,000       Series C
# 2        Eduisfun      Mumbai           Edtech   $28,000,000  Fresh funding
# 3        HomeLane     Chennai  Interior design   $30,000,000       Series D
# 4        Nu Genes   Telangana         AgriTech    $6,000,000            NaN

# %% [markdown]
# ### ii. Checking for Duplicates in The Dataset

# %%
# Create a boolean mask that identifies duplicates
duplicates = df_2019.duplicated(keep=False)

# Count the number of occurrences of each unique value in the boolean mask
value_counts = duplicates.value_counts()

# The value counts
value_counts
# Out:
# False    89
# dtype: int64

# %% [raw]
# There are no duplucates in the 2019 Dataset

# %% [markdown]
# ### iii. Checking for Missing Values in The Dataset

# %%
# check for Missing values in 2019 Dataset
missing_values = df_2019.isnull().sum()

# Number of missing values in each column
missing_values
# Out:
# Company/Brand     0
# HeadQuarter      19
# Sector            5
# Amount($)         0
# Stage            46
# dtype: int64

# %% [markdown]
# #### a). Cleaning the 'Headquarter' column

# %%
df_2019['HeadQuarter'].describe
# Out:
# <bound method NDFrame.describe of 0           NaN
# 1        Mumbai
# 2        Mumbai
# 3       Chennai
# 4     Telangana
#         ...
# 84       Mumbai
# 85     Gurugram
# 86        Delhi
# 87        Delhi
# 88    Rajasthan
# Name: HeadQuarter, Length: 89, dtype: object>

# %%
# Replace all missing values in the 'HeadQuarter' column with the string "Unavailable".
df_2019['HeadQuarter'] = df_2019['HeadQuarter'].fillna('Unavailable')
df_2019.head(15)
# Out:
#      Company/Brand  HeadQuarter           Sector     Amount($)          Stage
# 0   Bombay Shaving  Unavailable        Ecommerce    $6,300,000            NaN
# 1        Ruangguru       Mumbai           Edtech  $150,000,000       Series C
# 2         Eduisfun       Mumbai           Edtech   $28,000,000  Fresh funding
# 3         HomeLane      Chennai  Interior design   $30,000,000       Series D
# 4         Nu Genes    Telangana         AgriTech    $6,000,000            NaN
# 5         FlytBase         Pune       Technology   Undisclosed            NaN
# 6            Finly    Bangalore             SaaS   Undisclosed            NaN
# 7         Kratikal        Noida       Technology    $1,000,000   Pre series A
# 8        Quantiphi  Unavailable        AI & Tech   $20,000,000       Series A
# 9         Lenskart        Delhi       E-commerce  $275,000,000       Series G
# 10      Cub McPaws       Mumbai  E-commerce & AR   Undisclosed            NaN
# 11        Appnomic    Bangalore             SaaS   $22,000,000            NaN
# 12      Kaleidofin      Chennai          Fintech    $5,000,000       Series A
# 13       JobSquare    Ahmedabad          HR tech      $140,500            NaN
# 14     Open Secret  Unavailable        Food tech   Undisclosed            NaN

# %% [markdown]
# #### b). Cleaning the 'Sector' column

# %%
# Replace all missing values in the 'Sector' column with the string "Unknown".
df_2019['Sector'] = df_2019['Sector'].fillna('Unknown')
df_2019.head(50)
# Out:
#                    Company/Brand  HeadQuarter                Sector  \
# 0                 Bombay Shaving  Unavailable             Ecommerce
# 1                      Ruangguru       Mumbai                Edtech
# 2                       Eduisfun       Mumbai                Edtech
# 3                       HomeLane      Chennai       Interior design
# 4                       Nu Genes    Telangana              AgriTech
# 5                       FlytBase         Pune            Technology
# 6                          Finly    Bangalore                  SaaS
# 7                       Kratikal        Noida            Technology
# 8                      Quantiphi  Unavailable             AI & Tech
# 9                       Lenskart        Delhi            E-commerce
# 10                    Cub McPaws       Mumbai       E-commerce & AR
# 11                      Appnomic    Bangalore                  SaaS
# 12                    Kaleidofin      Chennai               Fintech
# 13                     JobSquare    Ahmedabad               HR tech
# 14                   Open Secret  Unavailable             Food tech
# 15                        LivFin        Delhi               Fintech
# 16                        Byju's  Unavailable                Edtech
# 17                    Zest Money    Bangalore               Fintech
# 18                       Witblox  Unavailable                Edtech
# 19  Azah Personal Care Pvt. Ltd.     Gurugram                Health
# 20                    SalaryFits  Unavailable               Fintech
# 21                  Pristyn Care  Unavailable            Healthcare
# 22                   Springboard  Unavailable                Edtech
# 23            DROR Labs Pvt. Ltd        Delhi           Safety tech
# 24                       Medlife    Bangalore        Pharmaceutical
# 25                       Seekify        Delhi                  SaaS
# 26              Toffee Insurance      Haryana  Insurance technology
# 27                 Fireflies .ai  Unavailable                    AI
# 28                     HungerBox    Bangalore              Foodtech
# 29                         Bijak  Unavailable              AgriTech
# 30                       Licious    Bangalore                  Food
# 31                         truMe  Unavailable                   IoT
# 32                      Pumpkart   Chandigarh         E-marketplace
# 33             Asteria Aerospace    Bangalore         Robotics & AI
# 34                        Rivigo  Unavailable             Logistics
# 35                   HappyEasyGo     Gurugram                Travel
# 36                       Zetwerk    Bangalore         Manufacturing
# 37                    Observe.AI    Bangalore                    AI
# 38                   Freshokartz       Jaipur         E-marketplace
# 39  Lil’ Goodness and sCool meal    Bangalore      Food & Nutrition
# 40                         Trell    Bangalore          Social Media
# 41                         VMate  Unavailable               Unknown
# 42          Bombay Shirt Company       Mumbai            E-commerce
# 43                       Slintel  Unavailable                  SaaS
# 44                    MyGameMate    Bangalore              E-Sports
# 45                        Afinoz        Noida               Fintech
# 46                    Rein Games        Noida            Technology
# 47                        Ecozen         Pune              AgriTech
# 48                          Box8       Mumbai              Foodtech
# 49             Awign Enterprises    Bangalore               Unknown
#
#        Amount($)          Stage
# 0     $6,300,000            NaN
# 1   $150,000,000       Series C
# 2    $28,000,000  Fresh funding
# 3    $30,000,000       Series D
# 4     $6,000,000            NaN
# 5    Undisclosed            NaN
# 6    Undisclosed            NaN
# 7     $1,000,000   Pre series A
# 8    $20,000,000       Series A
# 9   $275,000,000       Series G
# 10   Undisclosed            NaN
# 11   $22,000,000            NaN
# 12    $5,000,000       Series A
# 13      $140,500            NaN
# 14   Undisclosed            NaN
# 15    $5,000,000            NaN
# 16  $540,000,000            NaN
# 17   $15,000,000       Series B
# 18      $182,700            NaN
# 19   Undisclosed   Pre series A
# 20    $5,000,000            NaN
# 21   $12,000,000       Series B
# 22   $11,000,000  Post series A
# 23   Undisclosed            NaN
# 24   $15,500,000            NaN
# 25    $1,500,000   Seed funding
# 26    $5,500,000       Series A
# 27    $5,000,000            NaN
# 28   $12,000,000       Series C
# 29    $2,500,000      Seed fund
# 30   $30,000,000       Series E
# 31      $140,000            NaN
# 32   Undisclosed            NaN
# 33  $230,000,000            NaN
# 34   $20,000,000       Series F
# 35   $49,400,000      Series B+
# 36   $32,000,000       Series B
# 37   $26,000,000       Series A
# 38      $150,000   Pre series A
# 39      $400,000            NaN
# 40    $2,000,000   Pre series A
# 41  $100,000,000            NaN
# 42    $8,000,000            NaN
# 43    $1,500,000            NaN
# 44      $100,000            NaN
# 45   Undisclosed            NaN
# 46   $50,000,000   Pre series A
# 47    $6,000,000       Series A
# 48  $120,000,000            NaN
# 49    $4,000,000       Series A

# %%
df_2019['Sector'].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior design', 'AgriTech', 'Technology',
#        'SaaS', 'AI & Tech', 'E-commerce', 'E-commerce & AR', 'Fintech',
#        'HR tech', 'Food tech', 'Health', 'Healthcare', 'Safety tech',
#        'Pharmaceutical', 'Insurance technology', 'AI', 'Foodtech', 'Food',
#        'IoT', 'E-marketplace', 'Robotics & AI', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', 'Unknown',
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & tech', 'Accomodation', 'Automotive tech',
#        'Legal tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking'], dtype=object)

# %%
# Replace "Edtech" with "Edtech" in the 'Sector' column
df_2019['Sector'] = df_2019['Sector'].replace('Edtech', 'EdTech')
df_2019['Sector'].unique()
# Out:
# array(['Ecommerce', 'EdTech', 'Interior design', 'AgriTech', 'Technology',
#        'SaaS', 'AI & Tech', 'E-commerce', 'E-commerce & AR', 'Fintech',
#        'HR tech', 'Food tech', 'Health', 'Healthcare', 'Safety tech',
#        'Pharmaceutical', 'Insurance technology', 'AI', 'Foodtech', 'Food',
#        'IoT', 'E-marketplace', 'Robotics & AI', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', 'Unknown',
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & tech', 'Accomodation', 'Automotive tech',
#        'Legal tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking'], dtype=object)

# %% [markdown]
# #### c). Cleaning the 'Stage' column

# %%
# Replace all missing values in the 'Stage' column with the string "Unknown".
df_2019['Stage'] = df_2019['Stage'].fillna('Undisclosed')
df_2019.head(10)
# Out:
#     Company/Brand  HeadQuarter           Sector     Amount($)          Stage
# 0  Bombay Shaving  Unavailable        Ecommerce    $6,300,000    Undisclosed
# 1       Ruangguru       Mumbai           EdTech  $150,000,000       Series C
# 2        Eduisfun       Mumbai           EdTech   $28,000,000  Fresh funding
# 3        HomeLane      Chennai  Interior design   $30,000,000       Series D
# 4        Nu Genes    Telangana         AgriTech    $6,000,000    Undisclosed
# 5        FlytBase         Pune       Technology   Undisclosed    Undisclosed
# 6           Finly    Bangalore             SaaS   Undisclosed    Undisclosed
# 7        Kratikal        Noida       Technology    $1,000,000   Pre series A
# 8       Quantiphi  Unavailable        AI & Tech   $20,000,000       Series A
# 9        Lenskart        Delhi       E-commerce  $275,000,000       Series G

# %%
# Get unique funding stages
df_2019['Stage'].unique()
# Out:
# array(['Undisclosed', 'Series C', 'Fresh funding', 'Series D',
#        'Pre series A', 'Series A', 'Series G', 'Series B',
#        'Post series A', 'Seed funding', 'Seed fund', 'Series E',
#        'Series F', 'Series B+', 'Seed round', 'Pre-series A'],
#       dtype=object)

# %%
# Create a mapping dictionary that maps the variations to the standard representation
stage_mapping = {'Pre-series A': ['Pre series A'],
                 'Seed': ['Seed funding', 'Seed fund', 'Seed round'],
                 'Series A': ['Post series A'],
                 'Series B':['Series B+'],
                 'Undisclosed': ['Undisclosed','Fresh funding']}

# use a lambda function with the apply() function to map each funding stage based on the mapping dictionary.
df_2019['Stage'] = df_2019['Stage'].apply(lambda x: next((k for k, v in stage_mapping.items() if x in v), x))

# Confirm if changes have been effected
df_2019['Stage'].unique()
# Out:
# array(['Undisclosed', 'Series C', 'Series D', 'Pre-series A', 'Series A',
#        'Series G', 'Series B', 'Seed', 'Series E', 'Series F'],
#       dtype=object)

# %% [markdown]
# #### d). Cleaning the 'Amount' column, replacing any non-numeric values ("Undisclosed") with NaN, then converting the column to float datatype

# %%
# Replace currency symbol and commas with empty string
df_2019['Amount($)'] = df_2019['Amount($)'].str.replace(',', '', regex=False).str.replace('$', '', regex=False)

# Convert 'Amount' column to numeric datatype, replacing any non-numeric values with NaN using the 'coerce' option
df_2019['Amount($)'] = pd.to_numeric(df_2019['Amount($)'], errors='coerce')

# Convert Amount($) column from object to float datatype
df_2019['Amount($)'] = df_2019['Amount($)'].astype(float)

# The updated dataframe
df_2019.head(10)
# Out:
#     Company/Brand  HeadQuarter           Sector    Amount($)         Stage
# 0  Bombay Shaving  Unavailable        Ecommerce    6300000.0   Undisclosed
# 1       Ruangguru       Mumbai           EdTech  150000000.0      Series C
# 2        Eduisfun       Mumbai           EdTech   28000000.0   Undisclosed
# 3        HomeLane      Chennai  Interior design   30000000.0      Series D
# 4        Nu Genes    Telangana         AgriTech    6000000.0   Undisclosed
# 5        FlytBase         Pune       Technology          NaN   Undisclosed
# 6           Finly    Bangalore             SaaS          NaN   Undisclosed
# 7        Kratikal        Noida       Technology    1000000.0  Pre-series A
# 8       Quantiphi  Unavailable        AI & Tech   20000000.0      Series A
# 9        Lenskart        Delhi       E-commerce  275000000.0      Series G

# %%
# Plotting a kernel density (KDE) plot to show the distribution of values in the 'Amount($)' column for the year 2019.

sns.kdeplot(df_2019['Amount($)'])
plt.title('Kernel Density Plot of Amount($) in 2019')
plt.xlabel('Amount($)')
plt.xticks([0, 1e8, 2e8, 3e8, 4e8, 5e8, 6e8, 7e8, 8e8], ['0', '100M', '200M', '300M', '400M', '500M', '600M', '700M', '800M'])
plt.show()

# %% [raw]
# The kernel density plot (KDE) plot indicates that the majority of the investments made in 2019 were on the lower side, with a peak on the left-hand side of the distribution. This means that most investments were made for smaller amounts, with very few high-value investments since the peaks of the KDE Plot display where values are concentrated over the interval.
#
#
# The straight line observed after the 25th percentile indicates that there is not much variability in the higher value investments, which suggests that most of the investment amounts in this region are concentrated around a particular value.
#
# Regarding filling the NaN values in the 'Amount($)' column for 2019, the best measure of central tendency to use would depend on the distribution of the data. In this case, since the distribution is skewed towards the lower values, the best measure of central tendency to use would be the median. The median is less sensitive to outliers, which are likely to exist in this dataset. Thus, filling NaN values in the 'Amount($)' column with the median value would be a reasonable approach.

# %%
# Replace NaN values in 'Amount($)' column with the column's median value.
# Calculate the median of 'Amount($)' column
median_amount = df_2019['Amount($)'].median()

# Replace NaN values with median
df_2019['Amount($)'].fillna(median_amount, inplace=True)

# The updated dataframe
df_2019.head(10)
# Out:
#     Company/Brand  HeadQuarter           Sector    Amount($)         Stage
# 0  Bombay Shaving  Unavailable        Ecommerce    6300000.0   Undisclosed
# 1       Ruangguru       Mumbai           EdTech  150000000.0      Series C
# 2        Eduisfun       Mumbai           EdTech   28000000.0   Undisclosed
# 3        HomeLane      Chennai  Interior design   30000000.0      Series D
# 4        Nu Genes    Telangana         AgriTech    6000000.0   Undisclosed
# 5        FlytBase         Pune       Technology    6000000.0   Undisclosed
# 6           Finly    Bangalore             SaaS    6000000.0   Undisclosed
# 7        Kratikal        Noida       Technology    1000000.0  Pre-series A
# 8       Quantiphi  Unavailable        AI & Tech   20000000.0      Series A
# 9        Lenskart        Delhi       E-commerce  275000000.0      Series G

# %% [markdown]
# ### iv. Checking for Missing values and Confirming The data types again

# %%
# Check for Missing values in 2019 Dataset again
missing_values = df_2019.isnull().sum()

# Number of missing values in each column
missing_values
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# Stage            0
# dtype: int64

# %% [raw]
# All Missing Values in the 2019 dataset have been handled

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   HeadQuarter    89 non-null     object
#  2   Sector         89 non-null     object
#  3   Amount($)      89 non-null     float64
#  4   Stage          89 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 3.6+ KB

# %% [raw]
# The DataFrame is now formatted correctly to the respective data types.

# %% [markdown]
# ### v. Creating a new column 'Year' and setting it to 2019

# %%
# create a new column 'Year' and set it to 2019 to differentiate it from the other datasets
df_2019.insert(0,'Year', 2019) 
df_2019.head()
# Out:
#    Year   Company/Brand  HeadQuarter           Sector    Amount($)  \
# 0  2019  Bombay Shaving  Unavailable        Ecommerce    6300000.0
# 1  2019       Ruangguru       Mumbai           EdTech  150000000.0
# 2  2019        Eduisfun       Mumbai           EdTech   28000000.0
# 3  2019        HomeLane      Chennai  Interior design   30000000.0
# 4  2019        Nu Genes    Telangana         AgriTech    6000000.0
#
#          Stage
# 0  Undisclosed
# 1     Series C
# 2  Undisclosed
# 3     Series D
# 4  Undisclosed

# %% [markdown]
# # 3. The 2020 Dataset

# %%
df_2020
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu     NaN       Delhi              Edtech
# 1051         EpiFi     NaN         NaN             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# 3                          Escrow-as-a-service platform
# 4     Gramophone is an AgTech platform enabling acce...
# ...                                                 ...
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor    Amount($)       Stage  \
# 0                           Angel investors     $200,000         NaN
# 1                           GSF Accelerator     $100,000    Pre-seed
# 2                            Venture Center  Undisclosed    Pre-seed
# 3       Venture Catalysts, PointOne Capital     $400,000         NaN
# 4       Siana Capital Management, Info Edge     $340,000         NaN
# ...                                     ...          ...         ...
# 1050  DSG Consumer Partners, Blume Ventures   $1,500,000         NaN
# 1051          Sequoia India, Ribbit Capital  $13,200,000  Seed Round
# 1052                             Verlinvest   $8,000,000         NaN
# 1053             SIG Global India Fund LLP.   $8,043,000    Series C
# 1054                      Chiratae Ventures   $9,000,000    Series A
#
#      Unnamed: 9
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1050        NaN
# 1051        NaN
# 1052        NaN
# 1053        NaN
# 1054        NaN
#
# [1055 rows x 10 columns]

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1055 non-null   object
#  1   Founded        843 non-null    object
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What it does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount($)      1052 non-null   object
#  8   Stage          591 non-null    object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 82.5+ KB

# %% [markdown]
# # Cleaning The 2020 Dataset

# %% [markdown]
# ### i. Dropping the columns that are not needed for the analysis

# %%
# Drop the 'Founded' column
df_2020 = df_2020.drop('Founded', axis=1)

# Drop the 'What it does' column
df_2020 = df_2020.drop('What it does', axis=1)

# Drop the 'Founders' column
df_2020 = df_2020.drop('Founders', axis=1)

# Drop the 'Investor' column
df_2020 = df_2020.drop('Investor', axis=1)

# Drop the 'Unnamed: 9' column
df_2020 = df_2020.drop('Unnamed: 9', axis=1)

df_2020.head()
# Out:
#   Company/Brand HeadQuarter              Sector    Amount($)     Stage
# 0    Aqgromalin     Chennai            AgriTech     $200,000       NaN
# 1      Krayonnz   Bangalore              EdTech     $100,000  Pre-seed
# 2  PadCare Labs        Pune  Hygiene management  Undisclosed  Pre-seed
# 3         NCOME   New Delhi              Escrow     $400,000       NaN
# 4    Gramophone      Indore            AgriTech     $340,000       NaN

# %%
df_2019
# Out:
#     Year    Company/Brand  HeadQuarter                   Sector    Amount($)  \
# 0   2019   Bombay Shaving  Unavailable                Ecommerce    6300000.0
# 1   2019        Ruangguru       Mumbai                   EdTech  150000000.0
# 2   2019         Eduisfun       Mumbai                   EdTech   28000000.0
# 3   2019         HomeLane      Chennai          Interior design   30000000.0
# 4   2019         Nu Genes    Telangana                 AgriTech    6000000.0
# ..   ...              ...          ...                      ...          ...
# 84  2019     Infra.Market       Mumbai                Infratech   20000000.0
# 85  2019              Oyo     Gurugram              Hospitality  693000000.0
# 86  2019       GoMechanic        Delhi  Automobile & Technology    5000000.0
# 87  2019           Spinny        Delhi               Automobile   50000000.0
# 88  2019  Ess Kay Fincorp    Rajasthan                  Banking   33000000.0
#
#           Stage
# 0   Undisclosed
# 1      Series C
# 2   Undisclosed
# 3      Series D
# 4   Undisclosed
# ..          ...
# 84     Series A
# 85  Undisclosed
# 86     Series B
# 87  Undisclosed
# 88  Undisclosed
#
# [89 rows x 6 columns]

# %% [markdown]
# ### ii. Checking for Duplicates in The Dataset

# %%
# Create a boolean mask that identifies duplicates
duplicates = df_2020.duplicated(keep=False)

# Count the number of occurrences of each unique value in the boolean mask
value_counts = duplicates.value_counts()

# The value counts
value_counts
# Out:
# False    1043
# True       12
# dtype: int64

# %%
# Identify duplicate rows based on all columns
duplicates = df_2020[df_2020.duplicated(keep=False)]
duplicates
# Out:
#        Company/Brand HeadQuarter                 Sector     Amount($) Stage
# 120            Nykaa      Mumbai              Cosmetics   Undisclosed   NaN
# 129        Krimanshi     Jodhpur  Biotechnology company      $600,000  Seed
# 145        Krimanshi     Jodhpur  Biotechnology company      $600,000  Seed
# 205            Nykaa      Mumbai              Cosmetics   Undisclosed   NaN
# 215   Genius Teacher      Mumbai                 Edtech    $2,000,000   NaN
# 233   Genius Teacher      Mumbai                 Edtech    $2,000,000   NaN
# 326           Byju’s   Bangalore                 EdTech  $500,000,000   NaN
# 362           Byju’s   Bangalore                 EdTech  $500,000,000   NaN
# 771    Capital Float   Bangalore                Fintech   $15,000,000   NaN
# 935             Byju         NaN                 Edtech  $200,000,000   NaN
# 1014   Capital Float   Bangalore                Fintech   $15,000,000   NaN
# 1035            Byju         NaN                 Edtech  $200,000,000   NaN

# %%
# Drop the duplicate rows
df_2020.drop_duplicates(keep='first', inplace=True)

# %%
# Confirm if duplicate rows have been dropped
duplicates = df_2020[df_2020.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Company/Brand, HeadQuarter, Sector, Amount($), Stage]
# Index: []

# %% [markdown]
# ### iii. Checking for Missing Values in The Dataset

# %%
# check for Missing values in 2020 Dataset
missing_values = df_2020.isnull().sum()

# The number of missing values in each column
missing_values
# Out:
# Company/Brand      0
# HeadQuarter       93
# Sector            13
# Amount($)          3
# Stage            459
# dtype: int64

# %% [markdown]
# #### a). Cleaning the 'Headquarter' column

# %%
df_2020['HeadQuarter'].describe
# Out:
# <bound method NDFrame.describe of 0         Chennai
# 1       Bangalore
# 2            Pune
# 3       New Delhi
# 4          Indore
#           ...
# 1050        Delhi
# 1051          NaN
# 1052       Mumbai
# 1053        Delhi
# 1054      Chennai
# Name: HeadQuarter, Length: 1049, dtype: object>

# %%
# Replace all missing values in the 'HeadQuarter' column with the string "Unavailable".
df_2020['HeadQuarter'] = df_2020['HeadQuarter'].fillna('Unavailable')
df_2020.tail(15)
# Out:
#          Company/Brand  HeadQuarter                 Sector    Amount($)  \
# 1040          BuildPan       Indore                   SaaS  Undisclosed
# 1041           Shiksha  Unavailable                 Edtech     $181,000
# 1042    Super Surfaces    Hyderabad              Deisgning     $500,000
# 1043            Quicko    Ahmedabad               Taxation     $280,000
# 1044  Satin Creditcare      Gurgaon                Fintech  $15,000,000
# 1045        XpressBees  Unavailable              Logistics  $10,000,000
# 1046           FarmERP         Pune               Agritech  Undisclosed
# 1047     Wealth Bucket  Unavailable                Fintech   $3,000,000
# 1048        GoMechanic        Delhi  Automobile Technology  $14,700,000
# 1049            Fashor      Chennai                Fashion   $1,000,000
# 1050      Leverage Edu        Delhi                 Edtech   $1,500,000
# 1051             EpiFi  Unavailable                Fintech  $13,200,000
# 1052           Purplle       Mumbai              Cosmetics   $8,000,000
# 1053            Shuttl        Delhi              Transport   $8,043,000
# 1054             Pando      Chennai               Logitech   $9,000,000
#
#              Stage
# 1040    Seed Round
# 1041           NaN
# 1042      Series A
# 1043           NaN
# 1044           NaN
# 1045           NaN
# 1046      Series A
# 1047           NaN
# 1048      Series B
# 1049  Pre Series A
# 1050           NaN
# 1051    Seed Round
# 1052           NaN
# 1053      Series C
# 1054      Series A

# %%
# Bangalore and Bengaluru are different names for the same city.
# Replace all occurrences of 'Bengaluru' with 'Bangalore' to maintain consistency in our dataset.
df_2020['HeadQuarter'] = df_2020['HeadQuarter'].str.replace('Bengaluru', 'Bangalore', case=False)
df_2020
# Out:
#      Company/Brand  HeadQuarter              Sector    Amount($)       Stage
# 0       Aqgromalin      Chennai            AgriTech     $200,000         NaN
# 1         Krayonnz    Bangalore              EdTech     $100,000    Pre-seed
# 2     PadCare Labs         Pune  Hygiene management  Undisclosed    Pre-seed
# 3            NCOME    New Delhi              Escrow     $400,000         NaN
# 4       Gramophone       Indore            AgriTech     $340,000         NaN
# ...            ...          ...                 ...          ...         ...
# 1050  Leverage Edu        Delhi              Edtech   $1,500,000         NaN
# 1051         EpiFi  Unavailable             Fintech  $13,200,000  Seed Round
# 1052       Purplle       Mumbai           Cosmetics   $8,000,000         NaN
# 1053        Shuttl        Delhi           Transport   $8,043,000    Series C
# 1054         Pando      Chennai            Logitech   $9,000,000    Series A
#
# [1049 rows x 5 columns]

# %% [markdown]
# #### b). Cleaning the 'Sector' column

# %%
df_2020[730:750].head(20)
# Out:
#               Company/Brand  HeadQuarter           Sector    Amount($)  \
# 734                  Remedo        Noida       Healthtech  Undisclosed
# 735              News Reach    Ahmedabad            Media  Undisclosed
# 736                RoomSoom        Noida          Housing  Undisclosed
# 737                Pedagogy  Unavailable           Edtech     $400,000
# 738               Classplus        Delhi           Edtech   $8,200,000
# 739                 Medlife    Bangalore   Pharmaceutical  $15,500,000
# 740                    Qin1        Noida           Edtech  Undisclosed
# 741                   MYSUN        Delhi             Tech   $4,257,000
# 742                   ShopX    Bangalore        Ecommerce   $1,410,000
# 743                   Sarva  Unavailable  Yoga & wellness  Undisclosed
# 744              Expertrons       Mumbai               AI  Undisclosed
# 745               NewsBytes     Gurugram    Digital Media   $1,500,000
# 746                Wagonfly    Bangalore              NaN     $500,000
# 747                    NIRA  Unavailable          Fintech   $2,100,000
# 748              Convosight    Hyderabad   Data Analytics   $4,000,000
# 749                   Fittr         Pune          Fitness   $2,000,000
# 750                 AsknBid    Bangalore  Investment Tech  Undisclosed
# 751                  Bira91    Bangalore         Beverage  $20,000,000
# 752  Finaureus Technologies         Pune          Fintech  Undisclosed
# 753             Daily Ninja      Haryana        Ecommerce     $349,800
#
#             Stage
# 734  Pre series A
# 735           NaN
# 736           NaN
# 737           NaN
# 738      Series B
# 739           NaN
# 740           NaN
# 741  Pre series A
# 742           NaN
# 743           NaN
# 744    Seed Round
# 745      Series A
# 746           NaN
# 747  Pre series A
# 748  Pre series A
# 749           NaN
# 750           NaN
# 751      Series C
# 752  Pre series A
# 753           NaN

# %%
# Replace all missing values in the 'Sector' column with the string "Unknown".
df_2020['Sector'] = df_2020['Sector'].fillna('Unknown')
df_2020[730:750].head(20)
# Out:
#               Company/Brand  HeadQuarter           Sector    Amount($)  \
# 734                  Remedo        Noida       Healthtech  Undisclosed
# 735              News Reach    Ahmedabad            Media  Undisclosed
# 736                RoomSoom        Noida          Housing  Undisclosed
# 737                Pedagogy  Unavailable           Edtech     $400,000
# 738               Classplus        Delhi           Edtech   $8,200,000
# 739                 Medlife    Bangalore   Pharmaceutical  $15,500,000
# 740                    Qin1        Noida           Edtech  Undisclosed
# 741                   MYSUN        Delhi             Tech   $4,257,000
# 742                   ShopX    Bangalore        Ecommerce   $1,410,000
# 743                   Sarva  Unavailable  Yoga & wellness  Undisclosed
# 744              Expertrons       Mumbai               AI  Undisclosed
# 745               NewsBytes     Gurugram    Digital Media   $1,500,000
# 746                Wagonfly    Bangalore          Unknown     $500,000
# 747                    NIRA  Unavailable          Fintech   $2,100,000
# 748              Convosight    Hyderabad   Data Analytics   $4,000,000
# 749                   Fittr         Pune          Fitness   $2,000,000
# 750                 AsknBid    Bangalore  Investment Tech  Undisclosed
# 751                  Bira91    Bangalore         Beverage  $20,000,000
# 752  Finaureus Technologies         Pune          Fintech  Undisclosed
# 753             Daily Ninja      Haryana        Ecommerce     $349,800
#
#             Stage
# 734  Pre series A
# 735           NaN
# 736           NaN
# 737           NaN
# 738      Series B
# 739           NaN
# 740           NaN
# 741  Pre series A
# 742           NaN
# 743           NaN
# 744    Seed Round
# 745      Series A
# 746           NaN
# 747  Pre series A
# 748  Pre series A
# 749           NaN
# 750           NaN
# 751      Series C
# 752  Pre series A
# 753           NaN

# %%
# Replace "Edtech" with "Edtech" in the stages column of the 2019 dataset
df_2020['Sector'] = df_2020['Sector'].replace('Edtech', 'EdTech')
df_2020['Sector'] = df_2020['Sector'].replace('Fintech', 'FinTech')

# %% [markdown]
# #### c). Cleaning the 'Stage' column

# %%
df_2020.head(10)
# Out:
#   Company/Brand HeadQuarter               Sector    Amount($)         Stage
# 0    Aqgromalin     Chennai             AgriTech     $200,000           NaN
# 1      Krayonnz   Bangalore               EdTech     $100,000      Pre-seed
# 2  PadCare Labs        Pune   Hygiene management  Undisclosed      Pre-seed
# 3         NCOME   New Delhi               Escrow     $400,000           NaN
# 4    Gramophone      Indore             AgriTech     $340,000           NaN
# 5        qZense   Bangalore             AgriTech     $600,000          Seed
# 6  MyClassboard   Hyderabad               EdTech     $600,000  Pre-series A
# 7         Metvy     Gurgaon  Networking platform  Undisclosed    Pre-series
# 8        Rupeek   Bangalore              FinTech  $45,000,000      Series C
# 9     Gig India        Pune        Crowdsourcing   $1,000,000  Pre-series A

# %%
# Replace all missing values in the 'Stage' column with the string "Unknown".
df_2020['Stage'] = df_2020['Stage'].fillna('Undisclosed')
df_2020.head(10)
# Out:
#   Company/Brand HeadQuarter               Sector    Amount($)         Stage
# 0    Aqgromalin     Chennai             AgriTech     $200,000   Undisclosed
# 1      Krayonnz   Bangalore               EdTech     $100,000      Pre-seed
# 2  PadCare Labs        Pune   Hygiene management  Undisclosed      Pre-seed
# 3         NCOME   New Delhi               Escrow     $400,000   Undisclosed
# 4    Gramophone      Indore             AgriTech     $340,000   Undisclosed
# 5        qZense   Bangalore             AgriTech     $600,000          Seed
# 6  MyClassboard   Hyderabad               EdTech     $600,000  Pre-series A
# 7         Metvy     Gurgaon  Networking platform  Undisclosed    Pre-series
# 8        Rupeek   Bangalore              FinTech  $45,000,000      Series C
# 9     Gig India        Pune        Crowdsourcing   $1,000,000  Pre-series A

# %%
# Get unique funding stages
df_2020['Stage'].unique()
# Out:
# array(['Undisclosed', 'Pre-seed', 'Seed', 'Pre-series A', 'Pre-series',
#        'Series C', 'Series A', 'Series B', 'Debt', 'Pre-series C',
#        'Pre-series B', 'Series E', 'Bridge', 'Series D', 'Series B2',
#        'Series F', 'Pre- series A', 'Edge', 'Series H', 'Pre-Series B',
#        'Seed A', 'Series A-1', 'Seed Funding', 'Pre-Seed', 'Seed round',
#        'Pre-seed Round', 'Seed Round & Series A', 'Pre Series A',
#        'Pre seed Round', 'Angel Round', 'Pre series A1', 'Series E2',
#        'Pre series A', 'Seed Round', 'Bridge Round', 'Pre seed round',
#        'Pre series B', 'Pre series C', 'Seed Investment', 'Series D1',
#        'Mid series', 'Series C, D', 'Seed funding'], dtype=object)

# %% [raw]
# There are variations in the representation of the same funding stage, such as 'Pre-series A', 'Pre- series A', 'Pre-Series A', 'Pre series A1', 'Pre Series A', 'Pre series A', 'Pre series A', 'Pre series A', and 'Pre Series A'.

# %%
# Create a mapping dictionary that maps the variations to the standard representation
stage_mapping = {'Pre-seed':['Pre-seed','Pre-Seed','Pre seed Round','Pre seed round','Pre-seed Round'],
                 'Pre-series A': ['Pre-series A', 'Pre- series A', 'Pre-Series A', 
                                  'Pre series A1', 'Pre Series A','Pre-series','Pre series A'],
                 'Series A': ['Series A','Seed Round & Series A','Series A-1'],
                 'Series B': ['Series B','Pre-series B','Pre-Series B','Pre series B'],
                 'Series C': ['Series C','Pre-series C','Pre series C'],
                 'Series D': ['Series D','Series D1'],
                 'Series E': ['Series E','Series E2'],
                 'Angel': ['Angel','Angel Round'],
                 'Bridge': ['Bridge','Bridge Round'],
                 'Seed': ['Seed','Seed A','Seed funding','Seed Funding','Seed Investment','Seed round','Seed Round',],
                 'Undisclosed': ['Undisclosed','Edge','Mid series','Series C, D']}
                 

# use a lambda function with the apply() function to map each funding stage based on the mapping dictionary.
df_2020['Stage'] = df_2020['Stage'].apply(lambda x: next((k for k, v in stage_mapping.items() if x in v), x))

# Confirm if changes have been effected
df_2020['Stage'].unique()
# Out:
# array(['Undisclosed', 'Pre-seed', 'Seed', 'Pre-series A', 'Series C',
#        'Series A', 'Series B', 'Debt', 'Series E', 'Bridge', 'Series D',
#        'Series B2', 'Series F', 'Series H', 'Angel'], dtype=object)

# %% [markdown]
# #### d). Cleaning the 'Amount' column, replacing any non-numeric values ("Undisclosed") with NaN, then converting the column to float datatype

# %%
# Replace currency symbol and commas with empty string
df_2020['Amount($)'] = df_2020['Amount($)'].str.replace(',', '', regex=False).str.replace('$', '', regex=False)

# Convert 'Amount' column to numeric datatype, replacing any non-numeric values with NaN using the 'coerce' option
df_2020['Amount($)'] = pd.to_numeric(df_2020['Amount($)'], errors='coerce')

# Convert Amount($) column from object to float datatype
df_2020['Amount($)'] = df_2020['Amount($)'].astype(float)

# The updated dataframe
df_2020.head(10)
# Out:
#   Company/Brand HeadQuarter               Sector   Amount($)         Stage
# 0    Aqgromalin     Chennai             AgriTech    200000.0   Undisclosed
# 1      Krayonnz   Bangalore               EdTech    100000.0      Pre-seed
# 2  PadCare Labs        Pune   Hygiene management         NaN      Pre-seed
# 3         NCOME   New Delhi               Escrow    400000.0   Undisclosed
# 4    Gramophone      Indore             AgriTech    340000.0   Undisclosed
# 5        qZense   Bangalore             AgriTech    600000.0          Seed
# 6  MyClassboard   Hyderabad               EdTech    600000.0  Pre-series A
# 7         Metvy     Gurgaon  Networking platform         NaN  Pre-series A
# 8        Rupeek   Bangalore              FinTech  45000000.0      Series C
# 9     Gig India        Pune        Crowdsourcing   1000000.0  Pre-series A

# %%
# Create a violin plot to show the distribution of the amount raised in 2020
sns.violinplot(x=df_2020['Amount($)'])
plt.title('Distribution of Amount Raised in 2020')
# Set the x-axis label
plt.xlabel('Amount Raised in 2020 ($)')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [raw]
# Based on the violin plot, the measure of central tendency that would be appropriate for filling null values in the Amount column is the median. Since the distribution is skewed to the left and most of the investments were made for smaller amounts, the median would provide a more representative value than the mean, which could be affected by the presence of outliers or high-value investments. The fact that the white dot (which represents the median) is within the dense area on the left side of the distribution further supports this choice.

# %%
# Replace NaN values in 'Amount($)' column with the column's median value.
# Calculate the median of 'Amount($)' column
median_amount = df_2020['Amount($)'].median()

# Replace NaN values with median
df_2020['Amount($)'].fillna(median_amount, inplace=True)

# The updated dataframe
df_2020.head(10)
# Out:
#   Company/Brand HeadQuarter               Sector   Amount($)         Stage
# 0    Aqgromalin     Chennai             AgriTech    200000.0   Undisclosed
# 1      Krayonnz   Bangalore               EdTech    100000.0      Pre-seed
# 2  PadCare Labs        Pune   Hygiene management   3000000.0      Pre-seed
# 3         NCOME   New Delhi               Escrow    400000.0   Undisclosed
# 4    Gramophone      Indore             AgriTech    340000.0   Undisclosed
# 5        qZense   Bangalore             AgriTech    600000.0          Seed
# 6  MyClassboard   Hyderabad               EdTech    600000.0  Pre-series A
# 7         Metvy     Gurgaon  Networking platform   3000000.0  Pre-series A
# 8        Rupeek   Bangalore              FinTech  45000000.0      Series C
# 9     Gig India        Pune        Crowdsourcing   1000000.0  Pre-series A

# %%
# Calculate z-score for the 'Amount($)' column in df_2020 
z_scores = (df_2020['Amount($)'] - df_2020['Amount($)'].mean()) / df_2020['Amount($)'].std()

# Set a threshold for identifying outliers (e.g., z-score > 3 or z-score < -3)
outliers = df_2020[np.abs(z_scores) > 3]

# Display the outlier(s) and their corresponding information
outliers
# Out:
#                     Company/Brand HeadQuarter  Sector     Amount($)  \
# 280  Reliance Retail Ventures Ltd      Mumbai  Retail  7.000000e+10
#
#            Stage
# 280  Undisclosed

# %% [raw]
# Based on the z-score analysis, we have identified an outlier in the 'Amount($)' column of the df_2020 dataframe. The outlier corresponds to the startup 'Reliance Retail Ventures Ltd' located in Mumbai, with a funding amount of $70 billion (7.0e+10).

# %%
# Verify the funding amount for Alteria Capital and correct accordingly

# %% [raw]
# According to Crunchbase Alteria Capital raised a total of $6.4 billion in 2020.
# Source: https://www.crunchbase.com/organization/reliance-retail/company_financials

# %%
# Update the funding amount for Reliance Retail Ventures Ltd
# Replace with the correct funding amount
correct_amount = 6400000000
df_2020.loc[df_2020['Company/Brand'] == 'Reliance Retail Ventures Ltd', 'Amount($)'] = correct_amount

# %%
# # Confirm if there is any other instance of Reliance Retail Ventures in the 2020 dataset
# startup = df_2020[df_2020['Company/Brand'] == 'Reliance Retail Ventures']
# startup

# Find startups with "Reliance" in their names
reliance_startups = df_2020[df_2020['Company/Brand'].str.contains('Reliance')]
reliance_startups
# Out:
#                     Company/Brand HeadQuarter  \
# 165               Reliance Retail      Mumbai
# 280  Reliance Retail Ventures Ltd      Mumbai
# 302      Reliance Retail Ventures      Mumbai
# 328                      Reliance      Mumbai
# 364               Reliance Retail      Mumbai
#
#                                  Sector     Amount($)        Stage
# 165                          E-commerce  1.000000e+07  Undisclosed
# 280                              Retail  6.400000e+09  Undisclosed
# 302                          E-commerce  8.000000e+08  Undisclosed
# 328  Multinational conglomerate company  2.200000e+09  Undisclosed
# 364                          E-commerce  1.022000e+07  Undisclosed

# %%
# Drop all other Reliance instances since the Reliance Retail Ventures Ltd instance caters for all the funding raised by the company in 2020
index_to_drop = [165, 302, 328, 364]
df_2020 = df_2020.drop(index=index_to_drop)

# %% [markdown]
# ### iv. Checking for Missing values and Confirming The data typtes again

# %%
# check for Missing values in 2020 Dataset again
missing_values = df_2020.isnull().sum()

# Number of missing values in each column
missing_values
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# Stage            0
# dtype: int64

# %% [raw]
# All Missing Values in the 2020 dataset have been handled

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1045 entries, 0 to 1054
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1045 non-null   object
#  1   HeadQuarter    1045 non-null   object
#  2   Sector         1045 non-null   object
#  3   Amount($)      1045 non-null   float64
#  4   Stage          1045 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 49.0+ KB

# %% [raw]
# The DataFrame is now formatted correctly to the respective data types.

# %% [markdown]
# ### v. Creating a new column 'Year' and setting it to 2020

# %%
# create a new column 'Year' and set it to 2020 to differentiate it from the other datasets
df_2020.insert(0,'Year', 2020)
df_2020.head()
# Out:
#    Year Company/Brand HeadQuarter              Sector  Amount($)        Stage
# 0  2020    Aqgromalin     Chennai            AgriTech   200000.0  Undisclosed
# 1  2020      Krayonnz   Bangalore              EdTech   100000.0     Pre-seed
# 2  2020  PadCare Labs        Pune  Hygiene management  3000000.0     Pre-seed
# 3  2020         NCOME   New Delhi              Escrow   400000.0  Undisclosed
# 4  2020    Gramophone      Indore            AgriTech   340000.0  Undisclosed

# %% [markdown]
# # 4. The 2021 Dataset

# %%
df_2021.loc[254:257].head(15)
# Out:
#           Company/Brand  Founded             HeadQuarter  \
# 254     Evenflow Brands   2020.0                  Mumbai
# 255          MasterChow   2020.0        Food & Beverages
# 256  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 257             MoEVing   2021.0         Gurugram\t#REF!
#
#                                                 Sector  \
# 254                                     Consumer Goods
# 255                                          Hauz Khas
# 256  Primary Business is Development and Manufactur...
# 257  MoEVing is India's only Electric Mobility focu...
#
#                                           What it does  \
# 254  Identify and partner with the upcoming eCommer...
# 255                A ready-to-cook Asian cuisine brand
# 256                                       Varun Khanna
# 257                        Vikash Mishra, Mragank Jain
#
#                                            Founders      Investor Amount($)  \
# 254                   Utsav Agarwal, Pulkit Chhabra           NaN   $500000
# 255                   Vidur Kataria, Sidhanth Madan  WEH Ventures   $461000
# 256              Morgan Stanley Private Equity Asia     $22000000  Series C
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi      $5000000      Seed
#
#     Stage
# 254   NaN
# 255  Seed
# 256   NaN
# 257   NaN

# %% [raw]
# The dataset contains incorrect values in the 'HeadQuarter', 'Sector', 'What it does', 'Founders','Investor'.'Amount($)' and 'Stage' columns.
# The 'Headquarter Column contains values with a "\t#REF!" error.

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %% [markdown]
# # Cleaning The 2021 Dataset

# %% [markdown]
# ### i. Dropping the columns that are not needed for the analysis

# %%
# Drop the 'Founded' column
df_2021 = df_2021.drop('Founded', axis=1)

# Drop the 'What it does' column
df_2021 = df_2021.drop('What it does', axis=1)

# Drop the 'Founders' column
df_2021 = df_2021.drop('Founders', axis=1)

# Drop the 'Investor' column
df_2021 = df_2021.drop('Investor', axis=1)

df_2021.head()
# Out:
#     Company/Brand HeadQuarter          Sector     Amount($)         Stage
# 0  Unbox Robotics   Bangalore      AI startup    $1,200,000  Pre-series A
# 1          upGrad      Mumbai          EdTech  $120,000,000           NaN
# 2     Lead School      Mumbai          EdTech   $30,000,000      Series D
# 3         Bizongo      Mumbai  B2B E-commerce   $51,000,000      Series C
# 4        FypMoney    Gurugram         FinTech    $2,000,000          Seed

# %% [markdown]
# ### ii. Checking for Duplicates in The Dataset

# %% [raw]
# From the data understanding, some companies/brands have two or more rows because they raised several funding rounds in the same year. In such a case, these are not duplicates.

# %%
# Create a boolean mask that identifies duplicates
duplicates = df_2021.duplicated(keep=False)

# Count the number of occurrences of each unique value in the boolean mask
value_counts = duplicates.value_counts()

# The value counts
value_counts
# Out:
# False    1165
# True       44
# dtype: int64

# %%
# Identify duplicate rows based on all columns
duplicates = df_2021[df_2021.duplicated(keep=False)]
duplicates
# Out:
#            Company/Brand             HeadQuarter  \
# 94             Curefoods               Bangalore
# 96              Bewakoof                  Mumbai
# 98               FanPlay          Computer Games
# 104       Advantage Club                  Mumbai
# 106               Ruptok               New Delhi
# 107            Curefoods               Bangalore
# 109             Bewakoof                  Mumbai
# 111              FanPlay          Computer Games
# 117       Advantage Club                  Mumbai
# 119               Ruptok               New Delhi
# 229             Trinkerr               Bangalore
# 230                Zorro                Gurugram
# 231        Ultraviolette               Bangalore
# 232           NephroPlus               Hyderabad
# 233              Unremot               Bangalore
# 234          FanAnywhere               Bangalore
# 235           PingoLearn                    Pune
# 236                 Spry                  Mumbai
# 237              Enmovil               Hyderabad
# 238        ASQI Advisors                  Mumbai
# 239   Insurance Samadhan               New Delhi
# 240      Evenflow Brands                  Mumbai
# 241           MasterChow        Food & Beverages
# 242   Fullife Healthcare  Pharmaceuticals\t#REF!
# 243             Trinkerr               Bangalore
# 244                Zorro                Gurugram
# 245        Ultraviolette               Bangalore
# 246           NephroPlus               Hyderabad
# 247              Unremot               Bangalore
# 248          FanAnywhere               Bangalore
# 249           PingoLearn                    Pune
# 250                 Spry                  Mumbai
# 251              Enmovil               Hyderabad
# 252        ASQI Advisors                  Mumbai
# 253   Insurance Samadhan               New Delhi
# 254      Evenflow Brands                  Mumbai
# 255           MasterChow        Food & Beverages
# 256   Fullife Healthcare  Pharmaceuticals\t#REF!
# 351                Siply               Bangalore
# 401             BharatPe               New Delhi
# 416                Siply               Bangalore
# 847             BharatPe               New Delhi
# 973         Ola Electric               Bangalore
# 1076        Ola Electric               Bangalore
#
#                                                  Sector     Amount($)  \
# 94                                     Food & Beverages     $13000000
# 96                                    Apparel & Fashion      $8000000
# 98                                       Computer Games      Upsparks
# 104                                              HRTech      $1700000
# 106                                             FinTech      $1000000
# 107                                    Food & Beverages     $13000000
# 109                                   Apparel & Fashion      $8000000
# 111                                      Computer Games      Upsparks
# 117                                              HRTech      $1700000
# 119                                             FinTech      $1000000
# 229                                     Capital Markets      $6600000
# 230                                      Social network     $32000000
# 231                                          Automotive    $150000000
# 232                              Hospital & Health Care     $24000000
# 233                   Information Technology & Services       $700000
# 234                                  Financial Services  $Undisclosed
# 235                                          E-learning       $200000
# 236                                               Music      $1500000
# 237                   Information Technology & Services      $1300000
# 238                                  Financial Services      $1000000
# 239                                           Insurance       $725000
# 240                                      Consumer Goods       $500000
# 241                                           Hauz Khas       $461000
# 242   Primary Business is Development and Manufactur...      Series C
# 243                                     Capital Markets      $6600000
# 244                                      Social network     $32000000
# 245                                          Automotive    $150000000
# 246                              Hospital & Health Care     $24000000
# 247                   Information Technology & Services       $700000
# 248                                  Financial Services  $Undisclosed
# 249                                          E-learning       $200000
# 250                                               Music      $1500000
# 251                   Information Technology & Services      $1300000
# 252                                  Financial Services      $1000000
# 253                                           Insurance       $725000
# 254                                      Consumer Goods       $500000
# 255                                           Hauz Khas       $461000
# 256   Primary Business is Development and Manufactur...      Series C
# 351                                             FinTech    $1,000,000
# 401                                             FinTech    $6,000,000
# 416                                             FinTech    $1,000,000
# 847                                             FinTech    $6,000,000
# 973                                          Automotive    $200000000
# 1076                                         Automotive    $200000000
#
#              Stage
# 94             NaN
# 96             NaN
# 98        $1200000
# 104            NaN
# 106            NaN
# 107            NaN
# 109            NaN
# 111       $1200000
# 117            NaN
# 119            NaN
# 229       Series A
# 230           Seed
# 231       Series C
# 232       Series E
# 233           Seed
# 234           Seed
# 235            NaN
# 236           Seed
# 237   Pre-series A
# 238   Pre-series A
# 239   Pre-series A
# 240            NaN
# 241           Seed
# 242            NaN
# 243       Series A
# 244           Seed
# 245       Series C
# 246       Series E
# 247           Seed
# 248           Seed
# 249            NaN
# 250           Seed
# 251   Pre-series A
# 252   Pre-series A
# 253   Pre-series A
# 254            NaN
# 255           Seed
# 256            NaN
# 351           Seed
# 401           Debt
# 416           Seed
# 847           Debt
# 973            NaN
# 1076           NaN

# %% [raw]
# The 2021 dataset has 44 duplicate rows.

# %%
# Drop one of the duplicate rows
df_2021.drop_duplicates(keep='first', inplace=True)

# %%
# Confirm if duplicate rows have been dropped
duplicates = df_2021[df_2021.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Company/Brand, HeadQuarter, Sector, Amount($), Stage]
# Index: []

# %% [markdown]
# ### iii. Checking for Missing Values in The Dataset

# %%
# check for Missing values in 2021 Dataset
missing_values = df_2021.isnull().sum()

# The number of missing values in each column
missing_values
# Out:
# Company/Brand      0
# HeadQuarter        1
# Sector             0
# Amount($)          3
# Stage            420
# dtype: int64

# %% [markdown]
# #### a). Cleaning the 'Headquarter' column

# %%
df_2021['HeadQuarter'].describe()
# Out:
# count          1186
# unique           70
# top       Bangalore
# freq            419
# Name: HeadQuarter, dtype: object

# %%
# Replace all missing values in the 'HeadQuarter' column with the string "Unavailable".
df_2021['HeadQuarter'] = df_2021['HeadQuarter'].fillna('Unavailable')
df_2021.iloc[28:35].head(7)
# Out:
#    Company/Brand                  HeadQuarter          Sector   Amount($)  \
# 28    TrulyMadly                    New Delhi          Dating  $2,000,000
# 29      Vidyakul                  Unavailable          EdTech    $500,000
# 30  Jambox Games                    Bangalore          Gaming  $1,100,000
# 31          Miko                       Mumbai        Robotics  $6,000,000
# 32        SuperK  Small Towns, Andhra Pradesh          Retail    $800,000
# 33    TagZ Foods                    Bangalore            Food    $500,000
# 34    Fuel Buddy                    New Delhi  Oil and Energy  $1,000,000
#
#            Stage
# 28  Pre-series A
# 29          Seed
# 30          Seed
# 31           NaN
# 32          Seed
# 33  Pre-series A
# 34           NaN

# %%
# Handling the rows with the "\t#REF!" error

# filter based on the desired string
df_filtered = df_2021[df_2021['HeadQuarter'].str.contains('\t#REF!')]

# display the filtered dataframe
df_filtered
# Out:
#            Company/Brand             HeadQuarter  \
# 242   Fullife Healthcare  Pharmaceuticals\t#REF!
# 257              MoEVing         Gurugram\t#REF!
# 1100            Sochcast     Online Media\t#REF!
#
#                                                  Sector Amount($) Stage
# 242   Primary Business is Development and Manufactur...  Series C   NaN
# 257   MoEVing is India's only Electric Mobility focu...      Seed   NaN
# 1100  Sochcast is an Audio experiences company that ...       NaN   NaN

# %%
# Drop the rows with the "\t#REF!" error since almosy all columns contain wrong values
df_2021 = df_2021.drop(df_2021[df_2021['HeadQuarter'].str.contains('\t#REF!')].index)

# %% [markdown]
# #### b). Cleaning the 'Stage' column

# %% [markdown]
# ##### Handling Missing Values

# %%
# Replace all missing values in the 'Stage' column with the string "Unknown".
df_2021['Stage'] = df_2021['Stage'].fillna('Undisclosed')
df_2021.iloc[90:100].head(10)
# Out:
#    Company/Brand     HeadQuarter                    Sector     Amount($)  \
# 90  Studio Sirah       Bangalore            Computer Games       $800000
# 91   OTO Capital          Mumbai                   FinTech      $6000000
# 92       1Bridge       Bangalore            Consumer Goods      $2500000
# 93         Skeps        Gurugram                   FinTech      $9500000
# 94     Curefoods       Bangalore          Food & Beverages     $13000000
# 95   TartanSense       Bangalore    Information Technology      $5000000
# 96      Bewakoof          Mumbai         Apparel & Fashion      $8000000
# 97     Kirana247       New Delhi  Logistics & Supply Chain      $1000000
# 98       FanPlay  Computer Games            Computer Games      Upsparks
# 99       NeoDocs          Mumbai                Healthtech  $Undisclosed
#
#           Stage
# 90  Undisclosed
# 91  Undisclosed
# 92  Undisclosed
# 93  Undisclosed
# 94  Undisclosed
# 95  Undisclosed
# 96  Undisclosed
# 97  Undisclosed
# 98     $1200000
# 99  Undisclosed

# %%
# Get unique funding stages
df_2021['Stage'].unique()
# Out:
# array(['Pre-series A', 'Undisclosed', 'Series D', 'Series C', 'Seed',
#        'Series B', 'Series E', 'Pre-seed', 'Series A', 'Pre-series B',
#        'Debt', '$1200000', 'Bridge', 'Seed+', 'Series F2', 'Series A+',
#        'Series G', 'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', '$300000', 'Early seed', 'Series D1', '$6000000',
#        '$1000000', 'Seies A', 'Pre-series', 'Series A2', 'Series I'],
#       dtype=object)

# %%
# Create a mapping dictionary that maps the variations to the standard representation
stage_mapping = {'Pre-series A': ['Pre-series A', 'Pre-series A1','Early seed'],
                 'Seed':['Seed','Seed+','PE'],
                 'Series A': ['Series A','Series A+','Pre-series','Series A2','Seies A'],
                 'Series B': ['Series B','Pre-series B','Series B3'],
                 'Series C': ['Series C','Pre-series C','Pre series C'],
                 'Series D': ['Series D','Series D1'],
                 'Series F': ['Series F','Series F1','Series F2'],
                 'Angel': ['Angel','Angel Round'],
                 'Undisclosed': ['Undisclosed','Unknown']}
                 

# use a lambda function with the apply() function to map each funding stage based on the mapping dictionary.
df_2021['Stage'] = df_2021['Stage'].apply(lambda x: next((k for k, v in stage_mapping.items() if x in v), x))

# Confirm if changes have been effected
df_2021['Stage'].unique()
# Out:
# array(['Pre-series A', 'Undisclosed', 'Series D', 'Series C', 'Seed',
#        'Series B', 'Series E', 'Pre-seed', 'Series A', 'Debt', '$1200000',
#        'Bridge', 'Series F', 'Series G', 'Series H', '$300000',
#        '$6000000', '$1000000', 'Series I'], dtype=object)

# %% [markdown]
# ##### Handling incorrect values in the 'Amount($)', 'Stage' and 'HeadQuarter' columns

# %%
# Use str.contains() to find rows in the stage column that contain a dollar sign followed by a numerical value
dollar_amounts = df_2021[df_2021['Stage'].str.contains('\$\d+')]

# The resulting rows
dollar_amounts
# Out:
#         Company/Brand     HeadQuarter                  Sector  \
# 98            FanPlay  Computer Games          Computer Games
# 538       Little Leap       New Delhi                  EdTech
# 551             BHyve          Mumbai         Human Resources
# 674      MYRE Capital          Mumbai  Commercial Real Estate
# 677  Saarthi Pedagogy       Ahmadabad                  EdTech
#
#                            Amount($)     Stage
# 98                          Upsparks  $1200000
# 538                     ah! Ventures   $300000
# 551   ITO Angel Network, LetsVenture   $300000
# 674                              NaN  $6000000
# 677  JITO Angel Network, LetsVenture  $1000000

# %%
# Define a list of indices to modify
indices_to_modify = [98, 538, 551, 674, 677]

# Loop through the rows in the 'dollar_amounts' dataframe and replace the dollar amounts in the 'Stage' column with the values in the 'Amount($)' column for the specified indices
for index, row in dollar_amounts.iterrows():
    if index in indices_to_modify:
        amount = row['Stage']
        if pd.notnull(amount):
            df_2021.loc[index, 'Amount($)'] = str(amount)

# Loop through the rows in the 'df_2021' dataframe and replace the values in the 'Stage' column with NaN for the specified indices
for index in indices_to_modify:
    df_2021.loc[index, 'Stage'] = np.nan

# Display the modified dataframe
df_2021.loc[[98, 538, 551, 674, 677]]
# Out:
#         Company/Brand     HeadQuarter                  Sector Amount($) Stage
# 98            FanPlay  Computer Games          Computer Games  $1200000   NaN
# 538       Little Leap       New Delhi                  EdTech   $300000   NaN
# 551             BHyve          Mumbai         Human Resources   $300000   NaN
# 674      MYRE Capital          Mumbai  Commercial Real Estate  $6000000   NaN
# 677  Saarthi Pedagogy       Ahmadabad                  EdTech  $1000000   NaN

# %%
# Set the value at row 98 and column 'HeadQuarter' to NaN
df_2021.at[98, 'HeadQuarter'] = np.nan

# Display the modified dataframe
df_2021.loc[[98, 538, 551, 674, 677]]
# Out:
#         Company/Brand HeadQuarter                  Sector Amount($) Stage
# 98            FanPlay         NaN          Computer Games  $1200000   NaN
# 538       Little Leap   New Delhi                  EdTech   $300000   NaN
# 551             BHyve      Mumbai         Human Resources   $300000   NaN
# 674      MYRE Capital      Mumbai  Commercial Real Estate  $6000000   NaN
# 677  Saarthi Pedagogy   Ahmadabad                  EdTech  $1000000   NaN

# %%
# Handle the resultant missing values in the 'HeadQuarter' and 'Stage' columns
# Replace the missing value in index 98 of the 'HeadQuarter' column with the string "Unavailable".
df_2021.at[98, 'HeadQuarter'] = "Unavailable"

# Replace the missing values in indices 98, 538, 551, 674, and 677 of the 'Stage' column with the string "Unknown".
df_2021.loc[[98, 538, 551, 674, 677], 'Stage'] = "Unknown"

# Display the modified dataframe
df_2021.loc[[98, 538, 551, 674, 677]]
# Out:
#         Company/Brand  HeadQuarter                  Sector Amount($)    Stage
# 98            FanPlay  Unavailable          Computer Games  $1200000  Unknown
# 538       Little Leap    New Delhi                  EdTech   $300000  Unknown
# 551             BHyve       Mumbai         Human Resources   $300000  Unknown
# 674      MYRE Capital       Mumbai  Commercial Real Estate  $6000000  Unknown
# 677  Saarthi Pedagogy    Ahmadabad                  EdTech  $1000000  Unknown

# %% [markdown]
# ### d). Cleaning the 'Amount' column, replacing any non-numeric values ("Undisclosed" and "$Undisclosed") with NaN, then converting the column to float datatype

# %%
df_2021.loc[300:330].head(30)
# Out:
#            Company/Brand HeadQuarter                             Sector  \
# 300  Karkinos Healthcare      Mumbai             Hospital & Health Care
# 301     OWO Technologies    Gurugram                   Food & Beverages
# 302            EsportsXO   Bangalore                       Mobile Games
# 303      The Gourmet Jar       Noida                   Food & Beverages
# 304              Zorgers      Mohali             Hospital & Health Care
# 305               BangDB   Bangalore                  Computer Software
# 306      Neobank Jupiter      Mumbai                            Banking
# 307      Skippi Ice Pops   Hyderabad                    Food Production
# 308                 Glii       Noida                             Dating
# 309           GlobalBees   New Delhi                         E-commerce
# 310            Mamaearth    Gurugram         Health, Wellness & Fitness
# 311            SecureNow    Gurugram                          Insurance
# 312         Vendor Infra    Gurugram                       Construction
# 313        Hakuna Matata     Chennai  Information Technology & Services
# 314              OneCard        Pune                 Financial Services
# 315             Doubtnut    Gurugram                             EdTech
# 316            Hubhopper   New Delhi                            Podcast
# 317         Infra.Market       Thane                       Construction
# 318       Comofi Medtech   Bangalore                          HeathTech
# 319        Battery Smart   New Delhi                            Battery
# 320               Kutuki   Bangalore                             EdTech
# 321              Onelife      Mumbai                         Healthcare
# 322              Eupheus   New Delhi                             EdTech
# 323            KreditBee   Bangalore                            FinTech
# 324               Pencil      Mumbai                 Content publishing
# 325                Aisle   Bangalore                             Dating
# 326       Marquee Equity      Mumbai                            FinTech
# 327             UptimeAI   Bangalore                         AI startup
# 328              WizKlub   Bangalore                             EdTech
# 329                Zolve   Bangalore                            FinTech
#
#         Amount($)         Stage
# 300  $Undisclosed   Undisclosed
# 301      $3000000          Seed
# 302      $1100000          Seed
# 303       $150000   Undisclosed
# 304  $Undisclosed   Undisclosed
# 305  $Undisclosed   Undisclosed
# 306     $86000000      Series C
# 307       $130000   Undisclosed
# 308      $$100,00          Seed
# 309    $111000000      Series B
# 310     $37000000   Undisclosed
# 311      $6000000      Series B
# 312       $265000   Undisclosed
# 313      $1000000   Undisclosed
# 314     $76000000   Undisclosed
# 315   $30,000,000      Series B
# 316   Undisclosed   Undisclosed
# 317  $100,000,000      Series C
# 318      $200,000   Undisclosed
# 319   Undisclosed          Seed
# 320    $2,000,000          Seed
# 321   Undisclosed   Undisclosed
# 322    $4,000,000      Series B
# 323   $75,000,000      Series C
# 324    $1,000,000  Pre-series A
# 325   Undisclosed  Pre-series A
# 326    $3,800,000   Undisclosed
# 327    $1,500,000          Seed
# 328      $800,000  Pre-series A
# 329   $15,000,000          Seed

# %%
# Replace currency symbol($) and commas with empty string
df_2021['Amount($)'] = df_2021['Amount($)'].str.replace(',', '', regex=False).str.replace('$', '', regex=False)

# Convert to numeric datatype using the pd.to_numeric() function, with the 'coerce' option to convert non-numeric values to NaN.
df_2021['Amount($)'] = pd.to_numeric(df_2021['Amount($)'], errors='coerce')

# The updated dataframe
df_2021.loc[300:330].head(30)
# Out:
#            Company/Brand HeadQuarter                             Sector  \
# 300  Karkinos Healthcare      Mumbai             Hospital & Health Care
# 301     OWO Technologies    Gurugram                   Food & Beverages
# 302            EsportsXO   Bangalore                       Mobile Games
# 303      The Gourmet Jar       Noida                   Food & Beverages
# 304              Zorgers      Mohali             Hospital & Health Care
# 305               BangDB   Bangalore                  Computer Software
# 306      Neobank Jupiter      Mumbai                            Banking
# 307      Skippi Ice Pops   Hyderabad                    Food Production
# 308                 Glii       Noida                             Dating
# 309           GlobalBees   New Delhi                         E-commerce
# 310            Mamaearth    Gurugram         Health, Wellness & Fitness
# 311            SecureNow    Gurugram                          Insurance
# 312         Vendor Infra    Gurugram                       Construction
# 313        Hakuna Matata     Chennai  Information Technology & Services
# 314              OneCard        Pune                 Financial Services
# 315             Doubtnut    Gurugram                             EdTech
# 316            Hubhopper   New Delhi                            Podcast
# 317         Infra.Market       Thane                       Construction
# 318       Comofi Medtech   Bangalore                          HeathTech
# 319        Battery Smart   New Delhi                            Battery
# 320               Kutuki   Bangalore                             EdTech
# 321              Onelife      Mumbai                         Healthcare
# 322              Eupheus   New Delhi                             EdTech
# 323            KreditBee   Bangalore                            FinTech
# 324               Pencil      Mumbai                 Content publishing
# 325                Aisle   Bangalore                             Dating
# 326       Marquee Equity      Mumbai                            FinTech
# 327             UptimeAI   Bangalore                         AI startup
# 328              WizKlub   Bangalore                             EdTech
# 329                Zolve   Bangalore                            FinTech
#
#        Amount($)         Stage
# 300          NaN   Undisclosed
# 301    3000000.0          Seed
# 302    1100000.0          Seed
# 303     150000.0   Undisclosed
# 304          NaN   Undisclosed
# 305          NaN   Undisclosed
# 306   86000000.0      Series C
# 307     130000.0   Undisclosed
# 308      10000.0          Seed
# 309  111000000.0      Series B
# 310   37000000.0   Undisclosed
# 311    6000000.0      Series B
# 312     265000.0   Undisclosed
# 313    1000000.0   Undisclosed
# 314   76000000.0   Undisclosed
# 315   30000000.0      Series B
# 316          NaN   Undisclosed
# 317  100000000.0      Series C
# 318     200000.0   Undisclosed
# 319          NaN          Seed
# 320    2000000.0          Seed
# 321          NaN   Undisclosed
# 322    4000000.0      Series B
# 323   75000000.0      Series C
# 324    1000000.0  Pre-series A
# 325          NaN  Pre-series A
# 326    3800000.0   Undisclosed
# 327    1500000.0          Seed
# 328     800000.0  Pre-series A
# 329   15000000.0          Seed

# %%
# Plotting A histogram to visualize the distribution of funding amouns

# Histogram
plt.hist(df_2021['Amount($)'], bins=20)
plt.xlabel('Amount Raised in 2021 ($)')
plt.ylabel('Frequency')
plt.title('Distribution of Amount Raised in 2021')
plt.show()

# %% [raw]
# The histogram does not have a bell-shaped curve, indicating that it is not a normal distribution. Instead, it is asymmetrical indicating a positively skewed distribution since the data is clustered towards the left-hand side of the histogram.
# In this case, the the mean will be greater than the median, as the outliers on the right-hand side of the distribution pull the mean in that direction. To minimize the effect of outliers, it is appropriate to use the median as the measure of central tendency.
#
# However, it is worth noting that there is an outlier in the data, which is significantly higher than the rest of the funding amounts. This outlier may indicate a potential error or anomaly in the data and should be investigated further to ensure data integrity.

# %%
# Replace NaN values in 'Amount($)' column with median
# Calculate the median of 'Amount($)' column
median_amount = df_2021['Amount($)'].median()

# Replace NaN values with median
df_2021['Amount($)'].fillna(median_amount, inplace=True)

# The updated dataframe
df_2021.loc[300:330].head(30)
# Out:
#            Company/Brand HeadQuarter                             Sector  \
# 300  Karkinos Healthcare      Mumbai             Hospital & Health Care
# 301     OWO Technologies    Gurugram                   Food & Beverages
# 302            EsportsXO   Bangalore                       Mobile Games
# 303      The Gourmet Jar       Noida                   Food & Beverages
# 304              Zorgers      Mohali             Hospital & Health Care
# 305               BangDB   Bangalore                  Computer Software
# 306      Neobank Jupiter      Mumbai                            Banking
# 307      Skippi Ice Pops   Hyderabad                    Food Production
# 308                 Glii       Noida                             Dating
# 309           GlobalBees   New Delhi                         E-commerce
# 310            Mamaearth    Gurugram         Health, Wellness & Fitness
# 311            SecureNow    Gurugram                          Insurance
# 312         Vendor Infra    Gurugram                       Construction
# 313        Hakuna Matata     Chennai  Information Technology & Services
# 314              OneCard        Pune                 Financial Services
# 315             Doubtnut    Gurugram                             EdTech
# 316            Hubhopper   New Delhi                            Podcast
# 317         Infra.Market       Thane                       Construction
# 318       Comofi Medtech   Bangalore                          HeathTech
# 319        Battery Smart   New Delhi                            Battery
# 320               Kutuki   Bangalore                             EdTech
# 321              Onelife      Mumbai                         Healthcare
# 322              Eupheus   New Delhi                             EdTech
# 323            KreditBee   Bangalore                            FinTech
# 324               Pencil      Mumbai                 Content publishing
# 325                Aisle   Bangalore                             Dating
# 326       Marquee Equity      Mumbai                            FinTech
# 327             UptimeAI   Bangalore                         AI startup
# 328              WizKlub   Bangalore                             EdTech
# 329                Zolve   Bangalore                            FinTech
#
#        Amount($)         Stage
# 300    3500000.0   Undisclosed
# 301    3000000.0          Seed
# 302    1100000.0          Seed
# 303     150000.0   Undisclosed
# 304    3500000.0   Undisclosed
# 305    3500000.0   Undisclosed
# 306   86000000.0      Series C
# 307     130000.0   Undisclosed
# 308      10000.0          Seed
# 309  111000000.0      Series B
# 310   37000000.0   Undisclosed
# 311    6000000.0      Series B
# 312     265000.0   Undisclosed
# 313    1000000.0   Undisclosed
# 314   76000000.0   Undisclosed
# 315   30000000.0      Series B
# 316    3500000.0   Undisclosed
# 317  100000000.0      Series C
# 318     200000.0   Undisclosed
# 319    3500000.0          Seed
# 320    2000000.0          Seed
# 321    3500000.0   Undisclosed
# 322    4000000.0      Series B
# 323   75000000.0      Series C
# 324    1000000.0  Pre-series A
# 325    3500000.0  Pre-series A
# 326    3800000.0   Undisclosed
# 327    1500000.0          Seed
# 328     800000.0  Pre-series A
# 329   15000000.0          Seed

# %%
# Calculate z-score for the 'Amount($)' column in df_2021 
z_scores = (df_2021['Amount($)'] - df_2021['Amount($)'].mean()) / df_2021['Amount($)'].std()

# Set a threshold for identifying outliers (e.g., z-score > 3 or z-score < -3)
outliers = df_2021[np.abs(z_scores) > 3]

# Display the outlier(s) and their corresponding information
outliers
# Out:
#       Company/Brand HeadQuarter   Sector     Amount($) Stage
# 73  Alteria Capital      Mumbai  FinTech  1.500000e+11  Debt

# %% [raw]
# Based on the z-score analysis, we have identified an outlier in the 'Amount($)' column of the df_2021 dataframe. The outlier corresponds to the startup 'Alteria Capital' located in Mumbai, with a funding amount of $150 billion (1.5e+11).

# %%
# Verify the funding amount for Alteria Capital and correct accordingly

# %% [markdown]
# According to Crunchbase Alteria Capital raised ₹13.3B in 2021. This is equivalent to around $160510637.70
# Source: https://www.crunchbase.com/organization/alteria-capital/investor_financials

# %%
# Update the funding amount for Alteria Capital
# Replace with the correct funding amount
correct_amount = 160510637.70  
df_2021.loc[df_2021['Company/Brand'] == 'Alteria Capital', 'Amount($)'] = correct_amount

# %% [markdown]
# ### iv. Checking for Missing values and Confirming The data typtes again

# %%
# check for Missing values in 2020 Dataset again
missing_values = df_2021.isnull().sum()

# Number of missing values in each column
missing_values
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# Stage            0
# dtype: int64

# %% [raw]
# The dataset has no missing values

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1184 entries, 0 to 1208
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1184 non-null   object
#  1   HeadQuarter    1184 non-null   object
#  2   Sector         1184 non-null   object
#  3   Amount($)      1184 non-null   float64
#  4   Stage          1184 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 87.8+ KB

# %% [raw]
# All columns are formatted to the correct data type.

# %% [markdown]
# ### v. Creating a new column 'Year' and setting it to 2021

# %%
# create a new column 'Year' and set it to 2021 to differentiate it from the other datasets
df_2021.insert(0,'Year', 2021)
df_2021.head()
# Out:
#    Year   Company/Brand HeadQuarter          Sector    Amount($)         Stage
# 0  2021  Unbox Robotics   Bangalore      AI startup    1200000.0  Pre-series A
# 1  2021          upGrad      Mumbai          EdTech  120000000.0   Undisclosed
# 2  2021     Lead School      Mumbai          EdTech   30000000.0      Series D
# 3  2021         Bizongo      Mumbai  B2B E-commerce   51000000.0      Series C
# 4  2021        FypMoney    Gurugram         FinTech    2000000.0          Seed

# %% [markdown]
# # 5. Formatting The Datasets and Merging Them Into One File

# %% [markdown]
# ### i. Formatting The Columns of All Datasets To Ensure Consistency During Merging

# %%
# All the datasets have same number of columns but 1 has different column titles/labels from others

# Display the columns for each dataset
print("Columns of 2018 dataset:")
print(df_2018.columns)

print("Columns of 2019 dataset:")
print(df_2019.columns)

print("Columns of 2020 dataset:")
print(df_2020.columns)

print("Columns of 2021 dataset:")
print(df_2021.columns)
# Out:
# Columns of 2018 dataset:
# Index(['Year', 'Company Name', 'Industry', 'Round/Series', 'Amount($)',
#        'City'],
#       dtype='object')
# Columns of 2019 dataset:
# Index(['Year', 'Company/Brand', 'HeadQuarter', 'Sector', 'Amount($)', 'Stage'], dtype='object')
# Columns of 2020 dataset:
# Index(['Year', 'Company/Brand', 'HeadQuarter', 'Sector', 'Amount($)', 'Stage'], dtype='object')
# Columns of 2021 dataset:
# Index(['Year', 'Company/Brand', 'HeadQuarter', 'Sector', 'Amount($)', 'Stage'], dtype='object')

# %%
# Define a dictionary with the new column names
new_columns = {'Company Name': 'Company/Brand',
               'Industry': 'Sector',
               'Round/Series': 'Stage',
               'Amount($)': 'Amount($)',
               'City': 'HeadQuarter'}
    
# Rename the columns and rearrange them
df_2018 = df_2018.rename(columns=new_columns)
df_2018 = df_2018.reindex(columns=df_2019.columns)
df_2018.head()
# Out:
#    Year    Company/Brand HeadQuarter  \
# 0  2018  TheCollegeFever   Bangalore
# 1  2018  Happy Cow Dairy      Mumbai
# 2  2018       MyLoanCare     Gurgaon
# 3  2018      PayMe India       Noida
# 4  2018         Eunimart   Hyderabad
#
#                                               Sector  Amount($)     Stage
# 0  Brand Marketing, Event Promotion, Marketing, S...   250000.0      Seed
# 1                               Agriculture, Farming  1350000.0      Seed
# 2   Credit, Financial Services, Lending, Marketplace  1350000.0  Series A
# 3                        Financial Services, FinTech  2000000.0     Angel
# 4                 E-Commerce Platforms, Retail, SaaS  1350000.0      Seed

# %% [markdown]
# ### ii. Merging the datasets

# %%
# Merge datasets using concat function
merged_df = pd.concat([df_2018, df_2019, df_2020, df_2021], axis=0, ignore_index=True)

# Check if the merging has been effected.
merged_df.head(20)
# Out:
#     Year                     Company/Brand HeadQuarter  \
# 0   2018                   TheCollegeFever   Bangalore
# 1   2018                   Happy Cow Dairy      Mumbai
# 2   2018                        MyLoanCare     Gurgaon
# 3   2018                       PayMe India       Noida
# 4   2018                          Eunimart   Hyderabad
# 5   2018                            Hasura   Bangalore
# 6   2018                         Tripshelf     Kalkaji
# 7   2018                      Hyperdata.IO   Hyderabad
# 8   2018                      Freightwalla      Mumbai
# 9   2018                Microchip Payments   Bangalore
# 10  2018        BizCrum Infotech Pvt. Ltd.       Delhi
# 11  2018                           Emojifi   Bangalore
# 12  2018                             Flock       India
# 13  2018                         Freshboxx       Hubli
# 14  2018        Wide Mobility Mechatronics   Bangalore
# 15  2018                           Pitstop   Bangalore
# 16  2018                            Mihuru      Mumbai
# 17  2018                              Fyle   Bangalore
# 18  2018                          AppWharf   New Delhi
# 19  2018  Antariksh Waste Ventures Pvt ltd     Chennai
#
#                                                Sector  Amount($)     Stage
# 0   Brand Marketing, Event Promotion, Marketing, S...   250000.0      Seed
# 1                                Agriculture, Farming  1350000.0      Seed
# 2    Credit, Financial Services, Lending, Marketplace  1350000.0  Series A
# 3                         Financial Services, FinTech  2000000.0     Angel
# 4                  E-Commerce Platforms, Retail, SaaS  1350000.0      Seed
# 5                    Cloud Infrastructure, PaaS, SaaS  1600000.0      Seed
# 6                      Internet, Leisure, Marketplace  1350000.0      Seed
# 7                                     Market Research  1350000.0     Angel
# 8        Information Services, Information Technology  1350000.0      Seed
# 9                                     Mobile Payments  1350000.0      Seed
# 10                                         B2B, Shoes  1350000.0      Seed
# 11                                           Internet  1350000.0      Seed
# 12  Apps, Collaboration, Developer Platform, Enter...  1350000.0      Seed
# 13                                      Food Delivery  1350000.0      Seed
# 14                              Industrial Automation  1350000.0      Seed
# 15        Automotive, Search Engine, Service Industry  1350000.0      Seed
# 16                          Finance, Internet, Travel   150000.0      Seed
# 17  Accounting, Business Information Systems, Busi...  1100000.0      Seed
# 18  Artificial Intelligence, Product Search, SaaS,...  1350000.0      Seed
# 19               Internet of Things, Waste Management  1350000.0      Seed

# %% [markdown]
# ### iii. Check the integrity of Merged Data

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2843 entries, 0 to 2842
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           2843 non-null   int64
#  1   Company/Brand  2843 non-null   object
#  2   HeadQuarter    2843 non-null   object
#  3   Sector         2843 non-null   object
#  4   Amount($)      2843 non-null   float64
#  5   Stage          2843 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 133.4+ KB

# %%
# Check for NaN / Missing values
merged_df.isnull().sum()
# Out:
# Year             0
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# Stage            0
# dtype: int64

# %% [raw]
# The merged dataset has no missing values.

# %%
# Check for duplicates
merged_df.duplicated().sum()
# Out:
# 4

# %%
# Display the duplicate rows
duplicates = merged_df[merged_df.duplicated(keep=False)]
duplicates
# Out:
#       Year     Company/Brand HeadQuarter     Sector   Amount($)        Stage
# 632   2020         Pine Labs       Noida    FinTech   3000000.0  Undisclosed
# 1020  2020  FPL Technologies        Pune    FinTech  10000000.0     Series A
# 1032  2020     Lido Learning      Mumbai     EdTech   7500000.0     Series B
# 1118  2020  FPL Technologies        Pune    FinTech  10000000.0     Series A
# 1403  2020     Lido Learning      Mumbai     EdTech   7500000.0     Series B
# 1508  2020              Yolo    Gurugram  Transport    600000.0         Seed
# 1570  2020              Yolo    Gurugram  Transport    600000.0         Seed
# 1585  2020         Pine Labs       Noida    FinTech   3000000.0  Undisclosed

# %%
# Drop one of the duplicate rows
merged_df.drop_duplicates(keep='first', inplace=True)

# %%
# Confirm if duplicate rows have been dropped
duplicates = merged_df[merged_df.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Year, Company/Brand, HeadQuarter, Sector, Amount($), Stage]
# Index: []

# %% [raw]
# The merged dataset has no dulicate rows.

# %%
# Check for consistency
expected_rows = len(df_2018) + len(df_2019) + len(df_2020) + len(df_2021)
expected_cols = len(df_2019.columns)
if merged_df.shape == (expected_rows, expected_cols):
    print("The merged data has the expected number of rows and columns.")
else:
    print("The merged data does not have the expected number of rows and columns.")
# Out:
# The merged data does not have the expected number of rows and columns.

# %% [markdown]
# ### iv. Save the merged dataset to a new csv file

# %%
merged_df.to_csv('merged_df.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 1. Trend in startup funding in India over the years?

# %%
# Plotting a line graph to show the startup funding trends in India across the years (2018-2021)
# Filter the merged_df to include only the desired years
desired_years = [2018, 2019, 2020, 2021]
filtered_df = merged_df[merged_df['Year'].isin(desired_years)]

# Group the filtered data by year and calculate the total funding amount for each year
funding_by_year = filtered_df.groupby('Year')['Amount($)'].sum()

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(funding_by_year.index, funding_by_year.values, marker='o', color='purple')

# Set the labels and title
plt.xlabel('Year')
plt.ylabel('Total Funding Amount (in billions)')
plt.title('Trend in Startup Funding in India')

# Set the x-axis ticks to only display the desired years
plt.xticks(funding_by_year.index)

# Display the plot
plt.show()

# %% [raw]
# The total funding amount accessed by startups in India slightly grew between 2018 and 2019. From 2019 through to 2021, there was a consistent increase in the total funding amount accessed by Indian startups. Therefore, the funding landscape for Indian startups has experienced a notable transformation in recent years.

# %% [markdown]
# ### 2. What are the most common funding stage among Indian startups?

# %%
# A value counts of the 'Stage' column and using the .head(10) function to sort the top 10 stages in descending order.
top_10_stages = merged_df['Stage'].value_counts().head(10)

# Plot a bar chart of the number of Top 10 Most Popular Stages of Funding among Startups in India
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_stages.index, y=top_10_stages.values, palette='viridis')
plt.xlabel('Stage of Funding')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Most Popular Stages of Funding among Startups in India')
plt.show()

# %% [raw]
# The bar chart showcases the funding stages of startups in India. It highlights that a significant number of startups did not disclose their funding stages, while the most common disclosed stage was Seed. The chart also illustrates the progression from Seed to subsequent stages like Series A, Pre-series A, and Series B. Additionally, it reveals the presence of later-stage funding rounds such as Series C and Series D. The chart indicates the diversity of funding stages and the overall vibrancy of the Indian startup ecosystem.

# %% [markdown]
# ### 3. Average funding amount for a seed-stage investment in India over the years

# %%
# Filter the merged_df to include only seed-stage startups
seed_df = merged_df[merged_df['Stage'] == 'Seed']

# Group the data by year and calculate the mean funding amount for seed-stage startups
seed_df = seed_df.groupby('Year')['Amount($)'].mean().round()

# Create a new DataFrame with 'Year' and 'Amount' columns
seed_df = pd.DataFrame({'Year': seed_df.index, 'Amount': seed_df.values})
seed_df
# Out:
#    Year     Amount
# 0  2018  1224309.0
# 1  2019  2666667.0
# 2  2020  2144935.0
# 3  2021  3576326.0

# %%
# Plotting the funding years and average funding amount for seed-stage startups
plt.figure(figsize=(10, 6))
sns.lineplot(data=seed_df, x='Year', y='Amount', marker='o', color='purple')
plt.xlabel('Year')
plt.ylabel('Average Funding Amount ($)')
plt.title('Average Funding Amount for Seed-Stage Startups over the Years')
plt.xticks([2018, 2019, 2020, 2021])
plt.show()

# %% [raw]
# The line plot visualization illustrates the average seed funding trends in the Indian startup ecosystem over time. It shows a positive trend, indicating increasing investor interest and confidence in startups. There was a notable increase in average seed funding from 2018 to 2019, suggesting a favorable investment environment. However, there was a dip in funding between 2019 and 2020. The year 2020 saw a strong recovery with a sharp increase in average seed funding in the startup ecosystem.

# %% [markdown]
# ### 4.Which sector has the highest average funding amount?

# %%
# Plotting a horizontal bar graph showing the total funding amount for the top 10 sectors/industries in the Indian startup ecosystem.

# Calculate the total funding amount per sector by grouping the data based on the 'Sector' column and then summing the 'Amount($)' column. 
# .head(10) sorts the sectors in descending order and displays the top 10 sectors with the highest funding amount.
top_10_sectors = merged_df.groupby('Sector')['Amount($)'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_sectors.values, y=top_10_sectors.index, palette='viridis')
plt.xlabel('Total Funding Amount ($)')
plt.ylabel('Sector/Industry')
plt.title('Top 10 Sectors/Industries with Highest Funding Amount in the Indian Startup Ecosystem')
plt.show()

# %% [raw]
# The horizontal bar graph visualization highlights the funding distribution across different sectors in India. The Retail sector has received the highest funding amount, followed by EdTech and FinTech. The Tech company sector demonstrates a diverse range of startups, while the E-commerce sector continues to grow with significant funding for e-commerce platforms and logistics solutions.

# %% [markdown]
# ### 5: Is there a correlation between the location of a startup's headquarters and the amount of funding they receive?

# %%
# Group the data by headquarters location and calculate the total funding amount
location_funding = merged_df.groupby('HeadQuarter')['Amount($)'].sum()

# Sort the locations by funding amount in descending order
top_10_locations = location_funding.nlargest(10)

# Plot the total funding amount for the top 10 locations
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_locations.values, y=top_10_locations.index, palette='viridis')
plt.xlabel('Total Funding Amount')
plt.ylabel('Headquarters Location')
plt.title('Top 10 Locations with the Highest Total Funding Amount')

plt.show()

# %% [raw]
# Bangalore, Mumbai, Gurugram, New Delhi, and California are the top locations with the highest startup funding in the dataset.
# Each location offers unique advantages, such as a thriving ecosystem, access to funding, skilled talent, and industry networks.

# %% [markdown]
# ### 6. Which city has the highest number of startups?

# %%
# Do a count of the values for each headquarter in the merged_df
top_10_cities = merged_df['HeadQuarter'].value_counts().head()
top_10_cities
# Out:
# Bangalore      918
# Mumbai         462
# Gurugram       237
# New Delhi      229
# Unavailable    114
# Name: HeadQuarter, dtype: int64

# %%
# Plotting a treemap showing the top 5 cities with the highest number of startups in the Indian startup ecosystem.
plt.figure(figsize=(10, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(top_10_cities)))
squarify.plot(sizes=top_10_cities.values, label=[f'{c} ({v})' for c, v in zip(top_10_cities.index, top_10_cities.values)], color=colors, text_kwargs={'color': 'white'})
plt.axis('off')
plt.title('Top 10 Cities with the Highest Number of Startups (Treemap)')
plt.show()

# %% [raw]
# Bangalore has the highest number of startups in the dataset, followed by Mumbai, Gurugram, and New Delhi. These cities have a significant presence in the startup ecosystem, indicating a favorable environment for entrepreneurship and innovation.

# %% [markdown]
# ## Hypothesis Testing

# %%
# Create a contingency table of startup sector and funding status
contingency_table = pd.crosstab(merged_df['Sector'], merged_df['Stage'])

# Perform chi-square test
chi2, p_value, _, _ = stats.chi2_contingency(contingency_table)

# Set the significance level
alpha = 0.05

# Print the p_value
print(f"The P-value is {p_value}")
# Out:
# The P-value is 4.722720185763735e-186

# %%
# Compare the p-value with the significance level
if p_value < alpha:
    print("Reject the null hypothesis")
    print("A startup's sector has a significant influence on its ability to secure funding.")
else:
    print("Fail to reject the null hypothesis")
    print("There is no significant relationship between a startup's sector and its ability to secure funding.")
# Out:
# Reject the null hypothesis
# A startup's sector has a significant influence on its ability to secure funding.

# %% [raw]
# The obtained p-value (4.722720185763735e-186) is significantly smaller than the significance level of 0.05.
# This suggests a significant relationship between a startup's sector and its ability to secure funding.
# Considering the sector is crucial when assessing funding potential and developing strategies in the Indian startup ecosystem.

# %% [markdown]
# ## Insights and Recommendations

# %% [markdown]
# ### a).Insights

# %% [markdown]
# #### 1. The Indian startup ecosystem has shown resilience and consistent growth over the years.

# %% [raw]
# The funding landscape for Indian startups has experienced a notable transformation in recent years. The slight growth observed between 2018 and 2019 was followed by a period of steady and rapid expansion from 2019 to 2021. This indicates a positive trend and growing investor interest in the Indian startup ecosystem. The team should seize the opportunities presented by this favorable funding environment and leverage the increased investor confidence to explore new avenues for growth and innovation. By closely monitoring the evolving funding patterns and understanding the factors contributing to the surge in funding, the team can position themselves strategically to thrive in the dynamic startup landscape of India.

# %% [markdown]
# #### 2. Sectors like Retail, EdTech, FinTech, and Tech companies have received significant funding.

# %% [raw]
# The Retail sector stands out as the recipient of the highest total funding amount, underscoring the immense potential in retail technology and e-commerce startups. Following closely, the EdTech sector secures the second position in funding, emphasizing the significance of technology in revolutionizing education. Furthermore, the FinTech sector has garnered substantial funding, demonstrating robust investor interest and indicating a promising outlook for growth in this sector. These sectors represent potential areas of opportunity for startups to explore and tap into the investor interest.

# %% [markdown]
# #### 3. Seed-stage funding has a positive trend, indicating investor interest in early-stage startups.

# %% [raw]
# Seed is the most funded stage in the Indian startup ecosystem with the average seed-stage funding exhibiting a positive trend over the years. While there was a significant increase in average seed funding between 2018 and 2019, there was a temporary dip in 2020, likely influenced by economic conditions and the impact of the COVID-19 pandemic. However, there was a sharp rebound in seed funding in 2021, indicating renewed investor confidence.

# %% [markdown]
# #### 4. Top Cities with the Highest Number of Startups and Funding include Bangalore, Mumbai, Gurugram, and New Delhi.

# %% [raw]
# The analysis revealed that Bangalore, Mumbai, Gurugram, and New Delhi are the top locations with the highest startup funding and the highest number of startups in India. These locations are known for their thriving startup ecosystems and have attracted significant investment. Bangalore, also known as the Silicon Valley of India, offers a favorable environment with access to skilled talent and top-tier educational institutions. Mumbai, as the financial capital, has a strong presence of venture capital firms and investors. Gurugram, located in the NCR, has experienced substantial growth as a startup hub. New Delhi serves as a hub for startups seeking funding opportunities and collaboration. While California is not in India, it is significant in the global startup ecosystem due to Silicon Valley. Entrepreneurs and investors should consider these locations for their startup ventures, taking into account their unique advantages such as ecosystem strength, funding access, talent pool, and industry networks. The high number of startups in these cities indicates the availability of resources, support systems, and opportunities for aspiring entrepreneurs.

# %% [markdown]
# ### b). Recommendations

# %% [markdown]
# #### 1. Venture into the Indian startup ecosystem:

# %% [markdown]
# From the analysis of startup funding trends, the Indian startup ecosystem has shown resilience and consistent growth in recent years. The increasing funding amounts indicate investor confidence and a thriving entrepreneurial landscape. Therefore, venturing into the Indian startup ecosystem could be a promising course of action for the team.

# %% [markdown]
# #### 2. Focus on sectors with high funding potential:

# %% [raw]
# The analysis revealed that certain sectors in the Indian startup ecosystem have attracted significant funding. Sectors such as Retail, EdTech, FinTech, and Tech companies have received substantial investments. The team should consider exploring opportunities within these sectors, as they indicate strong investor interest and potential for growth.

# %% [markdown]
# #### 3. Target seed-stage funding opportunities.

# %% [raw]
# Seed is the most funded stage in the Indian startup ecosystem with the average seed funding showing a positive trend over the years (2018 - 2021). This indicates increased investor interest and confidence in startups. The team should leverage this trend by focusing on seed-stage funding opportunities, as they provide a solid foundation for startups and can lead to subsequent funding rounds.

# %% [markdown]
# #### 4. Consider establishing headquarters or a significant presence in key startup hubs.

# %% [raw]
# The hypothesis testing results indicated that there is a correlation between the location of a startup's headquarters and the funding amount they receive. Startups located in Bangalore, Mumbai, Gurugram, New Delhi, and California have shown higher funding amounts with the highest  number of startups also being headquartered in these locations. It is recommended to explore the geographical advantages of these locations, such as the presence of a thriving ecosystem, access to funding, skilled talent, and industry networks. Consider establishing a presence or partnerships in these locations to leverage these advantages and increase the chances of attracting higher funding.

# %% [markdown]
# #### 5. Monitor and adapt to funding trends.

# %% [raw]
# Startup funding trends can be dynamic and influenced by various factors. It is crucial that the team closely monitors the funding landscape, including changes in funding amounts, sectors attracting investment, and locations with high funding activity. Staying updated on market conditions, investor preferences, and emerging trends will enable us to adapt our strategies accordingly. This can be achieved through active participation in industry events, networking with investors, and staying connected with startup communities. Being aware of the evolving landscape will enable the team to align their strategies and positioning accordingly, increasing their chances of securing funding.

# %% [markdown]
# #### 6. Conduct further research and due diligence.

# %% [raw]
# The analysis provides valuable insights into the Indian startup ecosystem, but it is essential to conduct further research and due diligence. Explore additional datasets, industry reports, and market analyses to gain a comprehensive understanding of the ecosystem, including sector-specific opportunities, competition, regulatory considerations, and potential challenges.
